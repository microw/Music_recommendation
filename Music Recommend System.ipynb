# %% [markdown]
# ## 数据解析

# %% [markdown]
# ### 原始数据=>歌单数据 (此系统暂时只使用部分数据)
# 抽取 _**歌单名称，歌单id，收藏数，所属分类**_ 4个歌单维度的信息 <br>
# 抽取 _**歌曲id，歌曲名，歌手，歌曲热度**_ 等4个维度信息歌曲的信息<br>
#
# 组织成如下格式：
# ```
# 漫步西欧小镇上##小语种,旅行##69413685##474	18682332::Wäg vo dir::Joy Amelie::70.0	4335372::Only When I Sleep::The Corrs::60.0	2925502::Si Seulement::Lynnsha::100.0	21014930::Tu N'As Pas Cherché...::La Grande Sophie::100.0	20932638::Du behöver aldrig mer vara rädd::Lasse Lindh::25.0	17100518::Silent Machine::Cat Power::60.0	3308096::Kor pai kon diew : ชอไปคนเดียว::Palmy::5.0	1648250::les choristes::Petits Chanteurs De Saint Marc::100.0	4376212::Paddy's Green Shamrock Shore::The High Kings::25.0	2925400::A Todo Color::Las Escarlatinas::95.0	19711402::Comme Toi::Vox Angeli::75.0	3977526::Stay::Blue Cafe::100.0	2538518::Shake::Elize::85.0	2866799::Mon Ange::Jena Lee::85.0	5191949::Je M'appelle Helene::Hélène Rolles::85.0	20036323::Ich Lieb' Dich Immer Noch So Sehr::Kate & Ben::100.0

# %%
#coding: utf-8
import json
import sys

def parse_song_line(in_line):
    data = json.loads(in_line)
    name = data['result']['name']
    tags = ",".join(data['result']['tags'])
    subscribed_count = data['result']['subscribedCount']
    if(subscribed_count<100):
        return False
    playlist_id = data['result']['id']
    song_info = ''
    songs = data['result']['tracks']
    for song in songs:
        try:
            song_info += "\t"+"::".join([str(song['id']),song['name'],song['artists'][0]['name'],str(song['popularity'])])
        except Exception as e:
            #print (e)
            #print (song)
            continue
    return name+"##"+tags+"##"+str(playlist_id)+"##"+str(subscribed_count)+song_info

def parse_file(in_file, out_file):
    out = open(out_file, 'w', encoding='utf-8')
    for line in open(in_file, encoding='utf-8'):
        result = parse_song_line(line)
        if(result):
            out.write(result.strip()+"\n")
    out.close()
    

parse_file("./ori_data/playlist_detail_all.json", "./pro_data/163_music_playlist.txt")

# %% [markdown]
# ### 歌单数据=>推荐系统格式数据
# 主流的python推荐系统框架，支持的最基本数据格式为movielens dataset，其评分数据格式为 user item rating timestamp

# %%
import surprise 
import lightfm
# Out:
# D:\Anaconda\install\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '

# %% [markdown]
# ### 1.针对用户推荐 网易云音乐(每日30首歌/7首歌)
# ### 2.针对歌曲 在你听某首歌的时候，找“相似歌曲”

# %%
# 解析成userid itemid rating timestamp行格式
def is_null(s): 
    return len(s.split(","))>2

def parse_song_info(song_info):
    try:
        song_id, name, artist, popularity = song_info.split("::")
        #return ",".join([song_id, name, artist, popularity])
        return ",".join([song_id,"1.0",'1300000'])
    except Exception as e:
        #print (e)
        #print (song_info)
        return ""

def parse_playlist_line(in_line):
    try:
        contents = in_line.strip().split("\t")
        name, tags, playlist_id, subscribed_count = contents[0].split("##")
        songs_info = map(lambda x:playlist_id+","+parse_song_info(x), contents[1:])
        songs_info = filter(is_null, songs_info)
        return "\n".join(songs_info)
    except Exception as e:
        print (e)
        return False


def parse_file(in_file, out_file):
    out = open(out_file, 'w', encoding='utf-8')
    for line in open(in_file, encoding='utf-8'):
        result = parse_playlist_line(line)
        if(result):
            out.write(result.strip()+"\n")
    out.close()

# %%
parse_file("./pro_data/163_music_playlist.txt", "./pro_data/163_music_suprise_format.txt")

# %%
parse_file("./ori_data/popular.playlist", "./pro_data/popular_music_suprise_format.txt")

# %% [markdown]
# ### 保存歌单和歌曲信息备用
# 需要保存 **歌单id=>歌单名** 和 **歌曲id=>歌曲名** 的信息后期备用。

# %%
import pickle

def parse_playlist_get_info(in_line, playlist_dic, song_dic):
    contents = in_line.strip().split("\t")
    name, tags, playlist_id, subscribed_count = contents[0].split("##")
    playlist_dic[playlist_id] = name
    for song in contents[1:]:
        try:
            song_id, song_name, artist, popularity = song.split("::")
            song_dic[song_id] = song_name+"\t"+artist
        except:
            print ("song format error")
            print (song+"\n")



def parse_file1(in_file, out_playlist, out_song):
    #从歌单id到歌单名称的映射字典
    playlist_dic = {}
    #从歌曲id到歌曲名称的映射字典
    song_dic = {}
    for line in open(in_file, encoding='utf-8'):
        parse_playlist_get_info(line, playlist_dic, song_dic)
    #把映射字典保存在二进制文件中
    pickle.dump(playlist_dic, open(out_playlist,"wb")) 
    #可以通过 playlist_dic = pickle.load(open("playlist.pkl","rb"))重新载入
    pickle.dump(song_dic, open(out_song,"wb"))
    
    
def parse_file2(in_file, out_playlist, out_song):
    #从歌单id到歌单名称的映射字典
    playlist_dic = {}
    #从歌曲id到歌曲名称的映射字典
    song_dic = {}
    for line in open(in_file, encoding='utf-8'):
        parse_playlist_get_info(line, playlist_dic, song_dic)
    #把映射字典保存在二进制文件中
    pickle.dump(playlist_dic, open(out_playlist,"wb")) 
    #可以通过 playlist_dic = pickle.load(open("playlist.pkl","rb"))重新载入
    pickle.dump(song_dic, open(out_song,"wb"))

# %%
parse_file1("./pro_data/163_music_playlist.txt", "./pro_data/playlist.pkl", "./pro_data/song.pkl")
# Out:
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 532324::モノノ怪::オボロ怪~oboroge~::高梨康治::75.0
#
# song format error
# 4948095::银魂::决闘前には用を足せ::V.A.::75.0
#
# song format error
# 4949090::4代目青学&氷帝A::リフレッシュ 新たな自分へ|氷点下の情热II~THE TOPIII::日本ACG::15.0
#
# song format error
# 4949093::5代目青学&氷帝B::リフレッシュ 新たな自分へ|氷点下の情热II~THE TOPIII ~Forever with you Version.::日本ACG::5.0
#
# song format error
# 4949092::5代目青学&氷帝B::リフレッシュ 新たな自分へ|氷点下の情热II~THE TOPIII::日本ACG::5.0
#
# song format error
# 4967359::テニスの王子様::ここからが・・・俺達::V.A.::5.0
#
# song format error
# 4967372::テニスの王子様::南の岛から来た刺客::V.A.::15.0
#
# song format error
# 4967363::テニスの王子様::チャチャッと溃すぜ~Bloodshot::V.A.::15.0
#
# song format error
# 4967373::テニスの王子様::ここからが・・・俺達II
#
# song format error
# ::V.A.::5.0
#
# song format error
# 4967364::テニスの王子様::胜ちに执着する男::V.A.::5.0
#
# song format error
# 4967374::テニスの王子様::F.G.K.S::V.A.::5.0
#
# song format error
# 4967358::テニスの王子様::お前ら・・・崖っぷちギリギリ::V.A.::20.0
#
# song format error
# 4967369::テニスの王子様::俺を倒せ~お前は青学の柱になれ::V.A.::5.0
#
# song format error
# 4967361::テニスの王子様::俺は过去を凌驾する::V.A.::5.0
#
# song format error
# 4967365::テニスの王子様::负けることの许されない王者~非情のテニス::V.A.::20.0
#
# song format error
# 4967371::テニスの王子様::TOP OF THE STAGE FOR THE TENNIS::V.A.::5.0
#
# song format error
# 4967367::テニスの王子様::君を信じてる::V.A.::20.0
#
# song format error
# 4967370::テニスの王子様::SAMURAI::V.A.::5.0
#
# song format error
# 4967360::テニスの王子様::4年と2ヶ月と15日::V.A.::5.0
#
# song format error
# 4967362::テニスの王子様::4年と2か月と15日II::V.A.::5.0
#
# song format error
# 4967366::テニスの王子様::神懸りのテニス~だから勝つのは・・・::V.A.::5.0
#
# song format error
# 4967368::テニスの王子様::风林火山::V.A.::15.0
#
# song format error
# 573503::WHITE ALBUM::WHITE ALBUM::平野綾::90.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 376653::野弧禅狂叱(宿香之战)
#
# song format error
# ::霹雳英雄::5.0
#
# song format error
# 374524::赎?罪
#
# song format error
# 赎罪岩::霹雳英雄::15.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::65.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 31838468::Justiφ's(Tv Size Version)
#
# song format error
# ::佐藤和豊::25.0
#
# song format error
# 31246028::黒執事 華麗なるドラマCD::セバスチャンの執事ヴォイス 朝食のメニュー::小野大輔::40.0
#
# song format error
# 31246026::黒執事 華麗なるドラマCD::セバスチャンの執事ヴォイス 自己紹介::小野大輔::45.0
#
# song format error
# 548662::魔女の宅急便::海の见える街::山平宪嗣::35.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 548627::千と千寻の神隠し::いつも何度でも::山平宪嗣::50.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::30.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 37610597::ダウンタウン熱血物語::公園/河原にて~ひとときのやすらぎ~::V.A.::75.0
#
# song format error
# 37610748::くにおくんの熱血サッカーリーグ::ねっけつ たいふーん♪::V.A.::80.0
#
# song format error
# 37610755::くにおくんの熱血サッカーリーグ::てくのす じゃぱん かっぷの てーま♪::V.A.::75.0
#
# song format error
# 37610745::くにおくんの熱血サッカーリーグ::ゲームモード選択::V.A.::75.0
#
# song format error
# 37610643::ダウンタウン熱血行進曲 それゆけ大運動会::オープニングファンファーレ::V.A.::70.0
#
# song format error
# 423031::源氏物语::浮舟::藤原道山::65.0
#
# song format error
# 423026::源氏物语::紫の上晩歌::藤原道山::20.0
#
# song format error
# 422986::源氏物语::藤壷・管弦の宴::藤原道山::20.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 415975::The Time Walkers 1 天草四郎::オープニング::石田彰::5.0
#
# song format error
# 415980::The Time Walkers 1 天草四郎::岛原の乱::石田彰::5.0
#
# song format error
# 415985::The Time Walkers 1 天草四郎::难民キャンプ::石田彰::5.0
#
# song format error
# 415990::The Time Walkers 1 天草四郎::不思议な老人::石田彰::5.0
#
# song format error
# 415995::The Time Walkers 1 天草四郎::益田四郎时贞::石田彰::5.0
#
# song format error
# 415999::The Time Walkers 1 天草四郎::神の御子::石田彰::5.0
#
# song format error
# 416003::The Time Walkers 1 天草四郎::子供たち::石田彰::5.0
#
# song format error
# 416006::The Time Walkers 1 天草四郎::时の散歩者::石田彰::5.0
#
# song format error
# 416008::The Time Walkers 1 天草四郎::変えられぬ运命::石田彰::5.0
#
# song format error
# 416011::The Time Walkers 1 天草四郎::最后のミサ::石田彰::5.0
#
# song format error
# 416014::The Time Walkers 1 天草四郎::総攻撃::石田彰::5.0
#
# song format error
# 416019::The Time Walkers 1 天草四郎::歴史の真実::石田彰::5.0
#
# song format error
# 473245::TVアニメ“伯爵と妖精”::エドガー爱のポエム “亲爱なる君へ”::緑川光::15.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 456182::true tears::窓辺にもたれる少女 バイオリン ver.::菊地創::25.0
#
# song format error
# 785061::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝)::沙紗飛鳥::65.0
#
# song format error
# 33190071::Theme of Blood Blockade Battlefront
#
# song format error
# ::岩崎太整::65.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 4900971::となりのトトロ::风の通り道::M. Hisataakaa::45.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::30.0
#
# song format error
# 415975::The Time Walkers 1 天草四郎::オープニング::石田彰::15.0
#
# song format error
# 415980::The Time Walkers 1 天草四郎::岛原の乱::石田彰::5.0
#
# song format error
# 415985::The Time Walkers 1 天草四郎::难民キャンプ::石田彰::5.0
#
# song format error
# 415990::The Time Walkers 1 天草四郎::不思议な老人::石田彰::5.0
#
# song format error
# 415995::The Time Walkers 1 天草四郎::益田四郎时贞::石田彰::5.0
#
# song format error
# 415999::The Time Walkers 1 天草四郎::神の御子::石田彰::5.0
#
# song format error
# 416003::The Time Walkers 1 天草四郎::子供たち::石田彰::5.0
#
# song format error
# 416006::The Time Walkers 1 天草四郎::时の散歩者::石田彰::5.0
#
# song format error
# 416008::The Time Walkers 1 天草四郎::変えられぬ运命::石田彰::5.0
#
# song format error
# 416011::The Time Walkers 1 天草四郎::最后のミサ::石田彰::5.0
#
# song format error
# 416014::The Time Walkers 1 天草四郎::総攻撃::石田彰::15.0
#
# song format error
# 416019::The Time Walkers 1 天草四郎::歴史の真実::石田彰::5.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::90.0
#
# song format error
# 4960621::バンブーブレード::STAR RISE::広桥凉::40.0
#
# song format error
# 31090264::特捜エクシードラフト::特捜エクシードラフト::宮内タカユキ::25.0
#
# song format error
# 548662::魔女の宅急便::海の见える街::山平宪嗣::35.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 548670::千と千寻の神隠し::あの夏へ::山平宪嗣::25.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 518822::电脳コイル::悲しみの过去::斉藤恒芳::20.0
#
# song format error
# 33190071::Theme of Blood Blockade Battlefront
#
# song format error
# ::岩崎太整::65.0
#
# song format error
# 33190118::
#
# song format error
# Dust::Toft Willingham::60.0
#
# song format error
# 456194::true tears::ココロ重ねて::菊地創::75.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 415227::ラスト・フレンズ::Prisoner Of Love (Inst.Ver.) - instrumental::井筒昭雄::75.0
#
# song format error
# 473243::TVアニメ“伯爵と妖精”::my fairy::緑川光::60.0
#
# song format error
# 34696247::沖田総司 キャラクターイメージ曲::牙月::森久保祥太郎::20.0
#
# song format error
# 453365::TVアニメ“伯爵と妖精”::Wonder Ride::子安武人::15.0
#
# song format error
# 4959834::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::舞い戻ったワポル::V.A.::20.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 424496188::大王叫我来巡山 - （原唱：
#
# song format error
#  贾乃亮/贾云馨）::流浪的蛙蛙::65.0
#
# song format error
# 782899::纯情ロマンチカ サウンドコレクション Vol.1::木漏れ日::MOKA☆::35.0
#
# song format error
# 415227::ラスト・フレンズ::Prisoner Of Love (Inst.Ver.) - instrumental::井筒昭雄::75.0
#
# song format error
# 32272105::
#
# song format error
# Wonderful Love (DJ Raf Remix)::Money Penny::95.0
#
# song format error
# 1870957::彩云国物语 セカンドシリーズ::君を想う::梁邦彦::80.0
#
# song format error
# 427142111::ウタカタ
#
# song format error
# (原曲: ミストレイク)::Re:Volte::25.0
#
# song format error
# 31426924::乃木坂春香の秘密 DRAMA-CD 1 オーディオドラマ::『温泉旅行』の秘密::能登麻美子::5.0
#
# song format error
# 31426922::乃木坂春香の秘密 DRAMA-CD 1 オーディオドラマ::『乃木坂春香の秘密』の秘密::能登麻美子::5.0
#
# song format error
# 31426921::乃木坂春香の秘密 オーディオドラマ::『乃木坂美夏の麻衣ふぇあれいでぃお~乃木坂家メイド隊~』の秘密::能登麻美子::5.0
#
# song format error
# 31426919::乃木坂春香の秘密 オーディオドラマ::『乃木坂春香のドラマCD』の秘密::能登麻美子::5.0
#
# song format error
# 473243::TVアニメ“伯爵と妖精”::my fairy::緑川光::60.0
#
# song format error
# 548662::魔女の宅急便::海の见える街::山平宪嗣::35.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 29722334::For You
#
# song format error
# ::FiFi Rong::90.0
#
# song format error
# 4948078::银魂::掟は破るためにこそある::Audio Highs::50.0
#
# song format error
# 4948079::银魂::何ものにも染まらない黒::Audio Highs::45.0
#
# song format error
# 4948080::银魂::私と仕事どっちが大事なのとかいう女にはジャーマンスープレックス::Audio Highs::75.0
#
# song format error
# 4948081::银魂::夏休みは始まる前が一番楽しい::Audio Highs::35.0
#
# song format error
# 4948082::银魂::美は夏の果実の如き物::Audio Highs::75.0
#
# song format error
# 4948083::银魂::お前も糖人形にしてやろうか!::V.A.::30.0
#
# song format error
# 4948084::银魂::幽霊ネタやる时は慎重に::Audio Highs::25.0
#
# song format error
# 4948085::银魂::ずっと、ずっと一绪にいるよ::V.A.::35.0
#
# song format error
# 4948086::银魂::ほぼ100%の确率でビニール伞を置き忘れてくる自分が嫌い::Audio Highs::70.0
#
# song format error
# 4948087::银魂::4年目とかもういいんじゃね?::Audio Highs::50.0
#
# song format error
# 4948088::银魂::素人はプラスとマイナスだけで十分だ::V.A.::25.0
#
# song format error
# 4948089::银魂::くらいやがれぇぇぇぇ!!!::V.A.::25.0
#
# song format error
# 4948090::银魂::いつも心に一本のドライバー::Audio Highs::25.0
#
# song format error
# 4948091::银魂::ちゃんとお前らと繋がってんだよ::V.A.::25.0
#
# song format error
# 4948092::银魂::つーか、いつまでこんなことやってるアルか?::V.A.::25.0
#
# song format error
# 4948093::银魂::晴れの日に雨伞さす奴には御用心::Audio Highs::60.0
#
# song format error
# 4948094::银魂::夜王凤仙::V.A.::40.0
#
# song format error
# 4948095::银魂::决闘前には用を足せ::V.A.::75.0
#
# song format error
# 4948096::银魂::昼间に饮む酒は一味违う::V.A.::50.0
#
# song format error
# 4948097::银魂::安心してくたばれ、ダチ公::V.A.::70.0
#
# song format error
# 4948098::银魂::どんだけー!ギンタマン::V.A.::35.0
#
# song format error
# 4948099::银魂::どんだけー!小西マン::V.A.::25.0
#
# song format error
# 4948100::银魂::男は心に固ゆで卵::Audio Highs::35.0
#
# song format error
# 4948101::银魂::ハードボイルド同心 小銭形平次のテーマ壱 (ボーナストラック)::V.A.::25.0
#
# song format error
# 4948102::银魂::ハードボイルド同心 小銭形平次のテーマ弐 (ボーナストラック)::Audio Highs::25.0
#
# song format error
# 4948103::银魂::ハードボイルド同心 小銭形平次のテーマ参 (ボーナストラック)::V.A.::25.0
#
# song format error
# 4948104::银魂::ハードボイルド同心 小銭形平次のテーマ四 (ボーナストラック)::Audio Highs::25.0
#
# song format error
# 4948105::银魂::ハードボイルド同心 小銭形平次のテーマ伍 (ボーナストラック)::V.A.::25.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 28684643::勝利 ~Sengoku3 Mix~ [Bonus Track]
#
# song format error
# ::光栄BGM部::80.0
#
# song format error
# 28684644::死亡 ~Sengoku3 Mix~ [Bonus Track]
#
# song format error
# ::光栄BGM部::80.0
#
# song format error
# 28461972::Class::XIO_PROCEED;::志方あきこ::75.0
#
# song format error
# 28303294::Class::CIEL_N_PROTECTA;::南條愛乃＆リリィ::90.0
#
# song format error
# 28303296::Class::AR_NOSURGE#RE:Incarnation;::南條愛乃::35.0
#
# song format error
# 28461971::Class::CIEL_NOSURGE;::志方あきこ::25.0
#
# song format error
# 28303295::Class::EXPAJA;::南條愛乃::40.0
#
# song format error
# 28303298::Class::DISTLLISTA;::霜月はるか::70.0
# song format error
# 22773056::ODIN SPHERE’s Theme-Shanachie ver.-【エンディング】
#
# song format error
# ::崎元仁::15.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 33497915::
#
# song format error
# Frédéric Chopin: Ballade for piano No. 1 in G minor, Op. 23, CT. 2::Jorge Bolet::5.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 22499491::Job - A Masque for Dancing, Scene VII:: Pavane of the Sons of the Morning::Various Artists::5.0
#
# song format error
# 4964207::School Days-スクールデイズ-::茜色の空::大久保薫::55.0
#
# song format error
# 592112::エル・カザド::ennui::梶浦由記::15.0
#
# song format error
# 29722334::For You
#
# song format error
# ::FiFi Rong::90.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 1201294::Farewell She Whispered::cecilia::eyes::5.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 32272104::
#
# song format error
# Wonderful Love (Radio Edit)::Money Penny::80.0
#
# song format error
# 1870957::彩云国物语 セカンドシリーズ::君を想う::梁邦彦::80.0
#
# song format error
# 1870996::彩云国物语 セカンドシリーズ::典雅なる调べ::梁邦彦::25.0
#
# song format error
# 473243::TVアニメ“伯爵と妖精”::my fairy::緑川光::60.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 441612015::不客气
#
# song format error
# ::刘世超::60.0
#
# song format error
# 441612090::You're Welcome (Jordan Fisher/Lin-Manuel Miranda Version)
#
# song format error
# ::Lin-Manuel Miranda::35.0
#
# song format error
# 30474690::
#
# song format error
# Life Of Sin pt.2::MitiS::70.0
#
# song format error
# 4960603::バンブーブレード::BAMBOO BEAT::広桥凉::25.0
#
# song format error
# 4960621::バンブーブレード::STAR RISE::広桥凉::40.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 4948078::银魂::掟は破るためにこそある::Audio Highs::50.0
#
# song format error
# 4948079::银魂::何ものにも染まらない黒::Audio Highs::40.0
#
# song format error
# 4948080::银魂::私と仕事どっちが大事なのとかいう女にはジャーマンスープレックス::Audio Highs::75.0
#
# song format error
# 4948081::银魂::夏休みは始まる前が一番楽しい::Audio Highs::30.0
#
# song format error
# 4948082::银魂::美は夏の果実の如き物::Audio Highs::75.0
#
# song format error
# 4948083::银魂::お前も糖人形にしてやろうか!::V.A.::30.0
#
# song format error
# 4948084::银魂::幽霊ネタやる时は慎重に::Audio Highs::25.0
#
# song format error
# 4948085::银魂::ずっと、ずっと一绪にいるよ::V.A.::30.0
#
# song format error
# 4948086::银魂::ほぼ100%の确率でビニール伞を置き忘れてくる自分が嫌い::Audio Highs::70.0
#
# song format error
# 4948087::银魂::4年目とかもういいんじゃね?::Audio Highs::50.0
#
# song format error
# 4948088::银魂::素人はプラスとマイナスだけで十分だ::V.A.::25.0
#
# song format error
# 4948089::银魂::くらいやがれぇぇぇぇ!!!::V.A.::25.0
#
# song format error
# 4948090::银魂::いつも心に一本のドライバー::Audio Highs::25.0
#
# song format error
# 4948091::银魂::ちゃんとお前らと繋がってんだよ::V.A.::25.0
#
# song format error
# 4948092::银魂::つーか、いつまでこんなことやってるアルか?::V.A.::30.0
#
# song format error
# 4948093::银魂::晴れの日に雨伞さす奴には御用心::Audio Highs::60.0
#
# song format error
# 4948094::银魂::夜王凤仙::V.A.::40.0
#
# song format error
# 4948095::银魂::决闘前には用を足せ::V.A.::75.0
#
# song format error
# 4948096::银魂::昼间に饮む酒は一味违う::V.A.::45.0
#
# song format error
# 4948097::银魂::安心してくたばれ、ダチ公::V.A.::70.0
#
# song format error
# 4948098::银魂::どんだけー!ギンタマン::V.A.::35.0
#
# song format error
# 4948099::银魂::どんだけー!小西マン::V.A.::25.0
#
# song format error
# 4948100::银魂::男は心に固ゆで卵::Audio Highs::35.0
#
# song format error
# 4948101::银魂::ハードボイルド同心 小銭形平次のテーマ壱 (ボーナストラック)::V.A.::25.0
#
# song format error
# 4948102::银魂::ハードボイルド同心 小銭形平次のテーマ弐 (ボーナストラック)::Audio Highs::25.0
#
# song format error
# 4948103::银魂::ハードボイルド同心 小銭形平次のテーマ参 (ボーナストラック)::V.A.::25.0
#
# song format error
# 4948104::银魂::ハードボイルド同心 小銭形平次のテーマ四 (ボーナストラック)::Audio Highs::25.0
#
# song format error
# 4948105::银魂::ハードボイルド同心 小銭形平次のテーマ伍 (ボーナストラック)::V.A.::25.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::35.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 573503::WHITE ALBUM::WHITE ALBUM::平野綾::90.0
#
# song format error
# 26249479::Let's get “あと1センチ"
#
# song format error
# ::AKB48::20.0
#
# song format error
# 1342772::Swan Lake, Op.20 - Act 3 - No.20 Danse hongroise (Czárdás)
#
# song format error
# L'Orchestre de la Suisse Romande::Ernest Ansermet::5.0
#
# song format error
# 22527431::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Introduction::John Lanchbery::5.0
#
# song format error
# 22527432::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Adagio::John Lanchbery::5.0
#
# song format error
# 22527433::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Variation I:    The Fairy of the Crystal Fountain (Allegro::John Lanchbery::5.0
#
# song format error
# 22527434::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Variation II:   The Fairy of the Enchanted Garden (Allegro::John Lanchbery::5.0
#
# song format error
# 22527435::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Variation III:  The Fairy of the Woodland Glades (Allegro::John Lanchbery::5.0
#
# song format error
# 22527436::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Variation IV: The Fairy of the Songbirds (Moderato)::John Lanchbery::5.0
#
# song format error
# 22527437::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Variation V:  The Fairy of the Golden Vine (Allegro molto::John Lanchbery::5.0
#
# song format error
# 22527438::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Variation VI:  The Lilac Fairy (Tempo di valse)::John Lanchbery::15.0
#
# song format error
# 22527439::Sleeping Beauty Op. 66, Prologue: 'The Christening', 3.  Pas de six:: Coda (Allegro giusto)::John Lanchbery::5.0
#
# song format error
# 22527444::Sleeping Beauty Op. 66, Act I: 'The Spell', 8.  Pas d'action:: Rose Adagio (Andante - Adagio maestoso)::John Lanchbery::5.0
#
# song format error
# 22527445::Sleeping Beauty Op. 66, Act I: 'The Spell', 8.  Pas d'action:: Dance of the Maids of Honour and the Pages::John Lanchbery::5.0
#
# song format error
# 22527446::Sleeping Beauty Op. 66, Act I: 'The Spell', 8.  Pas d'action:: Aurora's Variation (Christopher Warren-Green, violin)::John Lanchbery::5.0
#
# song format error
# 22527447::Sleeping Beauty Op. 66, Act I: 'The Spell', 8.  Pas d'action:: Coda (Allegro giusto)::John Lanchbery::5.0
#
# song format error
# 22527468::Sleeping Beauty Op. 66, Act III: 'The Wedding', 23.  Pas de quatre:: Introduction (Allegro non tanto)::John Lanchbery::5.0
#
# song format error
# 22527469::Sleeping Beauty Op. 66, Act III: 'The Wedding', 23.  Pas de quatre:: Variation I:    The Golden Fairy (Allegro:  Tempo di valse)::John Lanchbery::5.0
#
# song format error
# 22527470::Sleeping Beauty Op. 66, Act III: 'The Wedding', 23.  Pas de quatre:: Variation II:   The Silver Fairy (Allegro giusto)::John Lanchbery::5.0
#
# song format error
# 22527471::Sleeping Beauty Op. 66, Act III: 'The Wedding', 23.  Pas de quatre:: Variation III:  The Sapphire Fairy (Vivacissimo)::John Lanchbery::5.0
#
# song format error
# 22527472::Sleeping Beauty Op. 66, Act III: 'The Wedding', 23.  Pas de quatre:: Variation IV: The Diamond Fairy (Vivace)::John Lanchbery::5.0
#
# song format error
# 22527473::Sleeping Beauty Op. 66, Act III: 'The Wedding', 23.  Pas de quatre:: Coda (L'istesso tempo)::John Lanchbery::5.0
#
# song format error
# 22527481::Sleeping Beauty Op. 66, Act III: 'The Wedding', 28.  Pas de deux (Aurora and Florimund):: Entreé (Allegretto - Allegro moderato)::John Lanchbery::5.0
#
# song format error
# 22527482::Sleeping Beauty Op. 66, Act III: 'The Wedding', 28.  Pas de deux (Aurora and Florimund):: Adagio (Andante non troppo)::John Lanchbery::5.0
#
# song format error
# 22527483::Sleeping Beauty Op. 66, Act III: 'The Wedding', 28.  Pas de deux (Aurora and Florimund):: Variation I:  Florimund (Vivace - Pres::John Lanchbery::5.0
#
# song format error
# 22527484::Sleeping Beauty Op. 66, Act III: 'The Wedding', 28.  Pas de deux (Aurora and Florimund):: Variation II: Aurora (Andantino) (Chri::John Lanchbery::20.0
#
# song format error
# 22527485::Sleeping Beauty Op. 66, Act III: 'The Wedding', 28.  Pas de deux (Aurora and Florimund):: Coda (Allegro vivace)::John Lanchbery::5.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 1201288::Our Longest Winter::cecilia::eyes::25.0
#
# song format error
# 423031::源氏物语::浮舟::藤原道山::65.0
#
# song format error
# 17742280::
#
# song format error
# Johann Sebastian Bach: Prelude and Fugue in C sharp (WTK, Book, No.3), BWV 848 - Prelude::Friedrich Gulda::25.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::35.0
#
# song format error
# 26883741::Concerto For Piano And Orchestra No.2 In E Major, BWV 1053 :
#
# song format error
# I. [Allegro]::Glenn Gould::20.0
#
# song format error
# 26883747::Concerto For Piano And Orchestra No.3 In D Major, BWV 1054 :
#
# song format error
# II. Adagio E Piano Sempre::Glenn Gould::20.0
#
# song format error
# 26883754::Concerto For Piano And Orchestra No.3 In D Major, BWV 1054 :
#
# song format error
# III. Allegro::Glenn Gould::20.0
#
# song format error
# 26883744::Concerto For Piano And Orchestra No.7 In G Minor, BWV 1058 :
#
# song format error
# I. [Allegro]::Glenn Gould::20.0
#
# song format error
# 26883757::Concerto For Piano And Orchestra No.7 In G Minor, BWV 1058 :
#
# song format error
# III. Allegro Assai::Glenn Gould::20.0
#
# song format error
# 604259::Sonata for Violin and Piano No. 3 in G minor (1917): I. Allegro vivo
#
# song format error
# Midori;Robert McDonald::五嶋美岛丽::10.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 617051::『となりのトトロ』より::となりのトトロ::桃井はるこ::10.0
#
# song format error
# 617100::『となりのトトロ』より::となりのトトロ(ファミソン オリジナル カラオケ(ショートサイズ))::桃井はるこ::10.0
#
# song format error
# 629606::崖の上のポニョ::崖の上のポニョ::中园理沙::15.0
#
# song format error
# 629609::ハウルの动く城::人生のメリーゴーランド::中园理沙::20.0
#
# song format error
# 629611::风の谷のナウシカ::风の谷のナウシカ::中园理沙::25.0
#
# song format error
# 629614::耳をすませば::バロンのうた::中园理沙::15.0
#
# song format error
# 629617::千と千寻の神隠し::いつも何度でも::中园理沙::20.0
#
# song format error
# 629622::天空の城ラピュタ::君をのせて::中园理沙::20.0
#
# song format error
# 629625::千と千寻の神隠し::あの日の川::中园理沙::20.0
#
# song format error
# 629627::となりのトトロ::风のとおり道::中园理沙::15.0
#
# song format error
# 629629::魔女の宅急便::旅立ち::中园理沙::50.0
#
# song format error
# 629633::もののけ姫::もののけ姫::中园理沙::10.0
#
# song format error
# 629636::ゲド戦记::テルーの呗::中园理沙::65.0
#
# song format error
# 629640::魔女の宅急便::海の见える街::中园理沙::70.0
#
# song format error
# 629642::となりのトトロ::さんぽ::中园理沙::10.0
#
# song format error
# 4900969::红の豚::マルコとジーナ::Lo Three S::20.0
#
# song format error
# 4900970::风の谷のナウシカ::风の伝説::Takero Ogata::20.0
#
# song format error
# 4900971::となりのトトロ::风の通り道::M. Hisataakaa::45.0
#
# song format error
# 4900972::魔女の宅急便::海の见える街::Lava::20.0
#
# song format error
# 4900973::ハウルの动く城::人生のメリーゴーランド::Morphil::20.0
#
# song format error
# 4900976::もののけ姫::アシタカとサン::DJ DAVI::20.0
#
# song format error
# 4900977::もののけ姫::もののけ姫::D.Locke::15.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::35.0
#
# song format error
# 4900980::ゲド戦记::テルーの呗::SMOOTH J::20.0
#
# song format error
# 415227::ラスト・フレンズ::Prisoner Of Love (Inst.Ver.) - instrumental::井筒昭雄::75.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 4954511::リズム天国全曲集::リミックス3 (恋のハニースイ~トエンジェル)::V.A.::25.0
#
# song format error
# 37610720::びっくり熱血新記録!はるかなる金メダル::おしまい::V.A.::65.0
#
# song format error
# 4954513::リズム天国全曲集::ナイトウォーク::V.A.::25.0
#
# song format error
# 4954645::リズム天国全曲集::ケロケロダンス Perfect Version(リズム天国ゴールド)[BONUS TRACK]::V.A.::5.0
#
# song format error
# 37610736::熱血格闘伝説::第5回戦::V.A.::50.0
#
# song format error
# 22455155::Don Giovanni (2002 Digital Remaster), Act I, Scene Three, Recitative & Aria:: Aria: Or sai chi l'onore (Donna Anna)::Various Artists::5.0
#
# song format error
# 545787::パパとムスメの7日间::7日间の思い出::山下康介::20.0
#
# song format error
# 4880130::正义の味方::槇子のテーマ.::小西康陽::20.0
#
# song format error
# 4880131::正义の味方::容子のツイスト.::小西康陽::70.0
#
# song format error
# 4880136::正义の味方::ピチカート・ポルカ::小西康陽::25.0
#
# song format error
# 4880139::正义の味方::槇子のカノン.::小西康陽::5.0
#
# song format error
# 415583::アタシんちの男子::アタシんちの男子::井筒昭雄::5.0
#
# song format error
# 422384::ROOKIES::ROOKIES ~爱のテーマ~::羽毛田丈史::25.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 4880131::正义の味方::容子のツイスト.::小西康陽::70.0
#
# song format error
# 1870957::彩云国物语 セカンドシリーズ::君を想う::梁邦彦::80.0
#
# song format error
# 803752::花衣梦衣::天翔る::Rin'::25.0
#
# song format error
# 803793::花衣梦衣::ひとひら、ふたひら (Rin’&Conisch Ver.)::Rin'::25.0
#
# song format error
# 548670::千と千寻の神隠し::あの夏へ::山平宪嗣::25.0
#
# song format error
# 1871012::彩云国物语 セカンドシリーズ::遥か远くへ::梁邦彦::50.0
#
# song format error
# 26884168::
#
# song format error
# Age Of Loneliness (Enigmatic Club Mix)::Enigma::5.0
#
# song format error
# 26884170::
#
# song format error
# Gravity Of Love (Judgement Day Club Mix)::Enigma::5.0
#
# song format error
# 26884172::
#
# song format error
# Light Of Your Smile::Enigma::5.0
#
# song format error
# 26884175::
#
# song format error
# Mea Culpa Part Ii (Original Version)::Enigma::5.0
#
# song format error
# 26884180::
#
# song format error
# Principles Of Lust (Omen Mix)::Enigma::5.0
#
# song format error
# 26884182::
#
# song format error
# Return To Innocence (380 Midnight)::Enigma::5.0
#
# song format error
# 26884183::
#
# song format error
# Return To Innocence (Long)::Enigma::15.0
#
# song format error
# 26884186::
#
# song format error
# Sadeness Part 1 (Meditation Mix)::Enigma::5.0
#
# song format error
# 22286071::Don Giovanni (2002 Digital Remaster), Act I, Scene Three, Recitative & Aria:: Aria: Dalla sua pace (Don Ottavio)::Carlo Maria Giulini::15.0
#
# song format error
# 17144702::Celtic Spirit Medley::::Celtic Spirit::5.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 29011079::
#
# song format error
# 真的很抱歉::棒棒堂::15.0
#
# song format error
# 26878881::
#
# song format error
# Wolfgang Amadeus Mozart: Serenata notturna in D, K.239 - 2. Menuetto - Trio::Herbert von Karajan::5.0
#
# song format error
# 28912617::Hymmn::LIGHT_HYMMN;::V.A.::5.0
#
# song format error
# 28912616::Hymmn::QUANTAM_NOVA;::V.A.::5.0
#
# song format error
# 28912618::Hymmn::FEMINI_SAT;::V.A.::5.0
#
# song format error
# 28912621::Hymmn::YU-KI_PERMITATION;::V.A.::5.0
#
# song format error
# 28912619::Hymmn::LIGHTHOUSE_NIGHT;::V.A.::5.0
#
# song format error
# 28912620::Hymmn::LIBO_PANDEMICS;::V.A.::5.0
#
# song format error
# 28461971::Class::CIEL_NOSURGE;::志方あきこ::25.0
#
# song format error
# 28461972::Class::XIO_PROCEED;::志方あきこ::80.0
#
# song format error
# 28461975::Hymmn::CHUMPI;::V.A.::15.0
#
# song format error
# 28461977::Hymmn::ARTIFICIAL_FLOWER;::V.A.::5.0
#
# song format error
# 28461980::Hymmn::AMENO_MURAKUMONO_MIKUJI;::V.A.::25.0
#
# song format error
# 28461982::Hymmn::TOKIKAGURA_TENTOUKI;::V.A.::5.0
#
# song format error
# 28461983::Hymmn::SEXY_METAL_IDOL;::V.A.::5.0
#
# song format error
# 28461984::Hymmn::I_HAVE_NO_ROYALTY_INCOME;::V.A.::5.0
#
# song format error
# 28461985::Hymmn::7TH_APOCALYPSE;::V.A.::5.0
#
# song format error
# 28303294::Class::CIEL_N_PROTECTA;::南條愛乃＆リリィ::90.0
#
# song format error
# 28303295::Class::EXPAJA;::南條愛乃::35.0
#
# song format error
# 28303296::Class::AR_NOSURGE#RE:Incarnation;::南條愛乃::35.0
#
# song format error
# 28303298::Class::DISTLLISTA;::霜月はるか::70.0
#
# song format error
# 28303299::Class::EXSPHERE_NOSURGE;::みとせのりこ::20.0
#
# song format error
# 28303302::Hymmn::TSUNDE_RAIN;::南條愛乃::20.0
#
# song format error
# 28303303::Hymmn::NEURON_KILLER_Z;::南條愛乃::20.0
#
# song format error
# 28303304::Hymmn::SPARTAN_LIB;::南條愛乃::20.0
#
# song format error
# 28303305::Hymmn::TOY_INSTALLER;::南條愛乃::20.0
#
# song format error
# 28303306::Hymmn::SCHIZOIDROPHIA;::南條愛乃::20.0
#
# song format error
# 28303307::Hymmn::BRIDAL_LAUNCH;::南條愛乃::20.0
#
# song format error
# 28303308::Hymmn::AR=CIEL_SPHERE;::南條愛乃::20.0
#
# song format error
# 29011079::
#
# song format error
# 真的很抱歉::棒棒堂::15.0
#
# song format error
# 1201288::Our Longest Winter::cecilia::eyes::25.0
#
# song format error
# 604259::Sonata for Violin and Piano No. 3 in G minor (1917): I. Allegro vivo
#
# song format error
# Midori;Robert McDonald::五嶋美岛丽::10.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 617048::『花の子ルンルン』より::花の子ルンルン::桃井はるこ::25.0
#
# song format error
# 617031::『山ねずみロッキーチャック』より::緑の阳だまり::桃井はるこ::20.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::35.0
#
# song format error
# 494715::おもひでぽろぽろ::メイン・テーマ::面谷誠二::25.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 22604898::Norma, Act 1 (1989 Digital Remaster), Cavatina:: Meco all'altar di Venere (Pollione)::Franco Corelli::5.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 494715::おもひでぽろぽろ::メイン・テーマ::面谷誠二::25.0
#
# song format error
# 548618::もののけ姫::もののけ姫::山平宪嗣::25.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 548627::千と千寻の神隠し::いつも何度でも::山平宪嗣::50.0
#
# song format error
# 548631::もののけ姫::アシタカ□记::山平宪嗣::25.0
#
# song format error
# 548635::となりのトトロ::となりのトトロ::山平宪嗣::20.0
#
# song format error
# 548641::ハウルの动く城::世界の约束::山平宪嗣::20.0
#
# song format error
# 548647::となりのトトロ::冢森の大树::山平宪嗣::20.0
#
# song format error
# 548652::ルパン三世 カリオストロの城::炎のたからもの::山平宪嗣::15.0
#
# song format error
# 548658::红の豚::帰らざる日々::山平宪嗣::20.0
#
# song format error
# 548662::魔女の宅急便::海の见える街::山平宪嗣::35.0
#
# song format error
# 548666::ハウルの动く城::人生のメリーゴーランド::山平宪嗣::20.0
#
# song format error
# 548670::千と千寻の神隠し::あの夏へ::山平宪嗣::25.0
#
# song format error
# 548676::红の豚::时には昔の话を::山平宪嗣::20.0
#
# song format error
# 548681::风の谷のナウシカ::风の谷のナウシカ-オープニング-::山平宪嗣::20.0
#
# song format error
# 548686::崖の上のポニョ::崖の上のポニョ::山平宪嗣::25.0
#
# song format error
# 4965892::桃华月惮::石剣-セキケン-::多田彰文::85.0
#
# song format error
# 28059284::Earth: The Oldest Computer (The Last Night) (feat. Macklemore)
#
# song format error
# ::Childish Gambino::20.0
#
# song format error
# 592076::エル・カザド::inca rose::梶浦由記::55.0
#
# song format error
# 592070::エル・カザド::sad yearning::梶浦由記::20.0
#
# song format error
# 415227::ラスト・フレンズ::Prisoner Of Love (Inst.Ver.) - instrumental::井筒昭雄::75.0
#
# song format error
# 423031::源氏物语::浮舟::藤原道山::60.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 27533077::夢を抱いて~はじまりのクリスロード~ (instrumental)
#
# song format error
#  - instrumental::Rake::35.0
#
# song format error
# 1201288::Our Longest Winter::cecilia::eyes::25.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 415219::るろうに剣心-明治剣客浪漫谭- 追忆编::In Memories ”KO・TO・WA・RI”::岩崎琢::25.0
#
# song format error
# 22773056::ODIN SPHERE’s Theme-Shanachie ver.-【エンディング】
#
# song format error
# ::崎元仁::15.0
#
# song format error
# 32408314::
#
# song format error
# Kishinjou set 03 ~ 運河を行き交う人妖::凛::20.0
#
# song format error
# 32408315::
#
# song format error
# Kishinjou set 04 ~ 柳の下のデュラハン::凛::15.0
#
# song format error
# 32408321::
#
# song format error
# Kishinjou set 09 ~ 空中に沈む輝針城::凛::5.0
#
# song format error
# 32408322::
#
# song format error
# Kishinjou set 10 ~ リバースイデオロギー::凛::20.0
#
# song format error
# 32408323::
#
# song format error
# Kishinjou set 11 ~ 針小棒大の天守閣::凛::15.0
#
# song format error
# 32408324::
#
# song format error
# Kishinjou set 12 ~ 輝く針の小人族::凛::20.0
#
# song format error
# 32408328::
#
# song format error
# Kishinjou set 16 ~ 不思議な不思議な道具達::凛::5.0
#
# song format error
# 32408334::
#
# song format error
# Amanojaku set 00 ~ 反則の狼煙を上げろ::凛::5.0
#
# song format error
# 32408335::
#
# song format error
# Amanojaku set 01 ~ 不可能弾幕には反則を::凛::15.0
#
# song format error
# 32408338::
#
# song format error
# Amanojaku set 03 ~ ロマンチック逃飛行::凛::15.0
#
# song format error
# 32408339::
#
# song format error
# Amanojaku set 04 ~ 永遠の三日天下::凛::15.0
#
# song format error
# 453365::TVアニメ“伯爵と妖精”::Wonder Ride::子安武人::15.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 37610771::熱血!ストリートバスケット::ハワイステージ::V.A.::25.0
#
# song format error
# 37610769::熱血!ストリートバスケット::テキサスステージ::V.A.::25.0
#
# song format error
# 37610767::熱血!ストリートバスケット::フロリダステージ::V.A.::25.0
#
# song format error
# 37610765::熱血!ストリートバスケット::US NAVYステージ::V.A.::25.0
#
# song format error
# 37610751::くにおくんの熱血サッカーリーグ::うんば・び・ぼんぼ♪::V.A.::55.0
#
# song format error
# 37610740::熱血格闘伝説::最終戦::V.A.::35.0
#
# song format error
# 37610714::びっくり熱血新記録!はるかなる金メダル::ハンマー投げ::V.A.::35.0
#
# song format error
# 37610716::びっくり熱血新記録!はるかなる金メダル::ビル越え棒幅跳び::V.A.::25.0
#
# song format error
# 37610680::いけいけ熱血ホッケー部 すべってころんで大乱闘::テクノスジャパンロゴ::V.A.::25.0
#
# song format error
# 4954529::リズム天国全曲集::ウサギとび::V.A.::20.0
#
# song format error
# 4954514::リズム天国全曲集::ザ☆ぼんおどり::V.A.::25.0
#
# song format error
# 4954541::リズム天国全曲集::メニュー::V.A.::20.0
#
# song format error
# 4954532::リズム天国全曲集::リズムお习字::V.A.::20.0
#
# song format error
# 4954523::リズム天国全曲集::エアーバッター::V.A.::20.0
#
# song format error
# 4954519::リズム天国全曲集::スーパータップ::V.A.::20.0
#
# song format error
# 4954511::リズム天国全曲集::リミックス3 (恋のハニースイ~トエンジェル)::V.A.::25.0
#
# song format error
# 4954512::リズム天国全曲集::リミックス5 (WISH 君を待てなくて)::V.A.::25.0
#
# song format error
# 37610583::熱血高校ドッチボール部::対ソ連・チームのテーマ::V.A.::50.0
#
# song format error
# 37610589::熱血高校ドッチボール部::対抗試合のテーマ::V.A.::25.0
#
# song format error
# 37610582::熱血高校ドッチボール部::対中国・チームのテーマ::V.A.::25.0
#
# song format error
# 37610760::熱血!ストリートバスケット::モード選択::V.A.::25.0
#
# song format error
# 37610757::くにおくんの熱血サッカーリーグ::エンディング::V.A.::25.0
#
# song format error
# 37610752::くにおくんの熱血サッカーリーグ::びきびき・さんば NO3♪::V.A.::40.0
#
# song format error
# 37610748::くにおくんの熱血サッカーリーグ::ねっけつ たいふーん♪::V.A.::80.0
#
# song format error
# 37610742::熱血格闘伝説::スタッフロール::V.A.::25.0
#
# song format error
# 37610741::熱血格闘伝説::エンディング::V.A.::25.0
#
# song format error
# 37610720::びっくり熱血新記録!はるかなる金メダル::おしまい::V.A.::65.0
#
# song format error
# 37610717::びっくり熱血新記録!はるかなる金メダル::はちゃめちゃ柔道::V.A.::25.0
#
# song format error
# 37610715::びっくり熱血新記録!はるかなる金メダル::水泳バトルロイヤル::V.A.::20.0
#
# song format error
# 37610711::びっくり熱血新記録!はるかなる金メダル::400mハードル::V.A.::40.0
#
# song format error
# 37610707::びっくり熱血新記録!はるかなる金メダル::モード選択::V.A.::25.0
#
# song format error
# 37610682::いけいけ熱血ホッケー部 すべってころんで大乱闘::タイトル::V.A.::20.0
#
# song format error
# 37610611::熱血高校ドッジボール部 サッカー編::テクノスジャパンロゴ::V.A.::20.0
#
# song format error
# 37610597::ダウンタウン熱血物語::公園/河原にて~ひとときのやすらぎ~::V.A.::75.0
#
# song format error
# 37610595::ダウンタウン熱血物語::ストーリー::V.A.::20.0
#
# song format error
# 37610599::ダウンタウン熱血物語::長谷部~愛のメロディー~::V.A.::20.0
#
# song format error
# 37610602::ダウンタウン熱血物語::大ボスのテーマ~五代/豪田登場~::V.A.::20.0
#
# song format error
# 37610605::ダウンタウン熱血物語::大決闘~最後の闘い~::V.A.::25.0
#
# song format error
# 37610603::ダウンタウン熱血物語::冷峰学園~対決!!~::V.A.::20.0
#
# song format error
# 37610735::熱血格闘伝説::第4回戦::V.A.::50.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 4954569::リズム天国全曲集::平凡::V.A.::15.0
#
# song format error
# 485103::レイトン教授と悪魔の箱 ::ちょっと一息::西浦智仁::5.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
# song format error
# ::f(x)::95.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::95.0
#
# song format error
# 785061::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝)::沙紗飛鳥::60.0
#
# song format error
# 1870986::彩云国物语 セカンドシリーズ::遥かなる想い─胡弓version::梁邦彦::20.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 4965892::桃华月惮::石剣-セキケン-::多田彰文::80.0
#
# song format error
# 532324::モノノ怪::オボロ怪~oboroge~::高梨康治::75.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::30.0
#
# song format error
# 494715::おもひでぽろぽろ::メイン・テーマ::面谷誠二::25.0
#
# song format error
# 4900970::风の谷のナウシカ::风の伝説::Takero Ogata::20.0
#
# song format error
# 4900972::魔女の宅急便::海の见える街::Lava::20.0
#
# song format error
# 4900979::千と千寻の神隠し::あの夏へ::Sal::30.0
#
# song format error
# 4900973::ハウルの动く城::人生のメリーゴーランド::Morphil::20.0
#
# song format error
# 4900977::もののけ姫::もののけ姫::D.Locke::15.0
#
# song format error
# 4900980::ゲド戦记::テルーの呗::SMOOTH J::20.0
#
# song format error
# 4900969::红の豚::マルコとジーナ::Lo Three S::20.0
#
# song format error
# 4900971::となりのトトロ::风の通り道::M. Hisataakaa::45.0
#
# song format error
# 4880316::Genius Party BABY BLUE::Criminals Usually Head South::V.A.::20.0
#
# song format error
# 4880309::Genius Party 梦みるキカイ::エプルーヴ (lepreuve)::V.A.::5.0
#
# song format error
# 803762::花衣梦衣::花衣::Rin'::60.0
#
# song format error
# 803771::花衣梦衣::梦衣::Rin'::50.0
#
# song format error
# 423031::源氏物语::浮舟::藤原道山::60.0
#
# song format error
# 803744::花衣梦衣::花衣梦衣::Rin'::20.0
#
# song format error
# 4960621::バンブーブレード::STAR RISE::広桥凉::40.0
#
# song format error
# 617067::『圣闘士星矢』より::ペガサス幻想(ファミソン オリジナル カラオケ(ショートサイズ))::桃井はるこ::75.0
#
# song format error
# 617031::『山ねずみロッキーチャック』より::緑の阳だまり::桃井はるこ::25.0
#
# song format error
# 617048::『花の子ルンルン』より::花の子ルンルン::桃井はるこ::20.0
#
# song format error
# 32272105::
#
# song format error
# Wonderful Love (DJ Raf Remix)::Money Penny::95.0
#
# song format error
# 573503::WHITE ALBUM::WHITE ALBUM::平野綾::90.0
#
# song format error
# 456126::true tears::无邪気さを背中に::菊地創::25.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 617019::『圣闘士星矢』より::ペガサス幻想::桃井はるこ::45.0
#
# song format error
# 617048::『花の子ルンルン』より::花の子ルンルン::桃井はるこ::25.0
#
# song format error
# 617031::『山ねずみロッキーチャック』より::緑の阳だまり::桃井はるこ::20.0
#
# song format error
# 26878881::
#
# song format error
# Wolfgang Amadeus Mozart: Serenata notturna in D, K.239 - 2. Menuetto - Trio::Herbert von Karajan::15.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 545701::パパとムスメの7日间::“パパとムスメの7日间”メインテーマ::山下康介::25.0
#
# song format error
# 415227::ラスト・フレンズ::Prisoner Of Love (Inst.Ver.) - instrumental::井筒昭雄::75.0
#
# song format error
# 415209::ラスト・フレンズ::フレンド・シップ::井筒昭雄::25.0
#
# song format error
# 415191::ラスト・フレンズ::スナップ・ショット::井筒昭雄::25.0
#
# song format error
# 415169::ラスト・フレンズ::ディア・フレンズ::井筒昭雄::20.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 1870957::彩云国物语 セカンドシリーズ::君を想う::梁邦彦::80.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 785061::幻奏ノ滝
#
# song format error
# 时音(フォールオブフォール~秋めく滝)::沙紗飛鳥::65.0
#
# song format error
# 617019::『圣闘士星矢』より::ペガサス幻想::桃井はるこ::45.0
#
# song format error
# 617098::『花の子ルンルン』より::花の子ルンルン(ファミソン オリジナル カラオケ(ショートサイズ))::桃井はるこ::10.0
#
# song format error
# 4951051::THE KING OF FIGHTERS 2002 UNLIMITED MATCH::KD-0079+::V.A.::60.0
#
# song format error
# 4951056::THE KING OF FIGHTERS 2002 UNLIMITED MATCH::二律背反~Mutually Exclusive Dichotomy~::V.A.::30.0
#
# song format error
# 589527::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク01::釘宮理恵::20.0
#
# song format error
# 589531::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク02::釘宮理恵::20.0
#
# song format error
# 589537::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク03::釘宮理恵::20.0
#
# song format error
# 589545::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク04::釘宮理恵::20.0
#
# song format error
# 589551::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク05::釘宮理恵::20.0
#
# song format error
# 589554::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク06::釘宮理恵::20.0
#
# song format error
# 589558::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク07::釘宮理恵::20.0
#
# song format error
# 589566::THE IDOLM@STER MASTER ARTIST 08 水瀬伊织::トーク08::釘宮理恵::20.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 27582794::
#
# song format error
# 丑三つ時の里::黄昏フロンティア::25.0
#
# song format error
# 686282::Chapter1 MainBGM
#
# song format error
# PSP ver::ARTERY VEIN::55.0
#
# song format error
# 27582794::
#
# song format error
# 丑三つ時の里::黄昏フロンティア::25.0
#
# song format error
# 494715::おもひでぽろぽろ::メイン・テーマ::面谷誠二::25.0
#
# song format error
# 548618::もののけ姫::もののけ姫::山平宪嗣::25.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 548627::千と千寻の神隠し::いつも何度でも::山平宪嗣::50.0
#
# song format error
# 548631::もののけ姫::アシタカ□记::山平宪嗣::25.0
#
# song format error
# 548635::となりのトトロ::となりのトトロ::山平宪嗣::20.0
#
# song format error
# 548641::ハウルの动く城::世界の约束::山平宪嗣::20.0
#
# song format error
# 548647::となりのトトロ::冢森の大树::山平宪嗣::20.0
#
# song format error
# 548652::ルパン三世 カリオストロの城::炎のたからもの::山平宪嗣::15.0
#
# song format error
# 548658::红の豚::帰らざる日々::山平宪嗣::20.0
#
# song format error
# 548662::魔女の宅急便::海の见える街::山平宪嗣::35.0
#
# song format error
# 548666::ハウルの动く城::人生のメリーゴーランド::山平宪嗣::20.0
#
# song format error
# 548670::千と千寻の神隠し::あの夏へ::山平宪嗣::25.0
#
# song format error
# 548676::红の豚::时には昔の话を::山平宪嗣::15.0
#
# song format error
# 548681::风の谷のナウシカ::风の谷のナウシカ-オープニング-::山平宪嗣::20.0
#
# song format error
# 548686::崖の上のポニョ::崖の上のポニョ::山平宪嗣::25.0
#
# song format error
# 543634::江南の大国・呉の参戦
#
# song format error
# ::横山菁児::60.0
#
# song format error
# 28059284::Earth: The Oldest Computer (The Last Night) (feat. Macklemore)
#
# song format error
# ::Childish Gambino::20.0
#
# song format error
# 4948086::银魂::ほぼ100%の确率でビニール伞を置き忘れてくる自分が嫌い::Audio Highs::70.0
#
# song format error
# 4948084::银魂::幽霊ネタやる时は慎重に::Audio Highs::25.0
#
# song format error
# 686282::Chapter1 MainBGM
#
# song format error
# PSP ver::ARTERY VEIN::55.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 573503::WHITE ALBUM::WHITE ALBUM::平野綾::90.0
#
# song format error
# 5157818::Divertimento in D, K.334 - 3. Menuetto - Trio -
#
# song format error
# Menuetto::Wiener MozartEnsemble::20.0
#
# song format error
# 29005604::
#
# song format error
# Sehnsucht nach dem Frühling ("Komm, lieber Mai"), song for voice & pian::Sky::85.0
#
# song format error
# 2772431::Sonata for piano & violin no.5:: II. Adagio molto espressivo::Isabelle Faust::20.0
#
# song format error
# 686282::Chapter1 MainBGM
#
# song format error
# PSP ver::ARTERY VEIN::55.0
#
# song format error
# 4965892::桃华月惮::石剣-セキケン-::多田彰文::85.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 4964190::School Days-スクールデイズ-::见ているだけで…::大久保薫::85.0
#
# song format error
# 31704021::
#
# song format error
# Te Iria A Buscar::DatPhoria::15.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 37610744::くにおくんの熱血サッカーリーグ::オープニング::V.A.::60.0
#
# song format error
# 37610745::くにおくんの熱血サッカーリーグ::ゲームモード選択::V.A.::75.0
#
# song format error
# 37610746::くにおくんの熱血サッカーリーグ::対戦チーム選択::V.A.::20.0
#
# song format error
# 37610747::くにおくんの熱血サッカーリーグ::VS画面::V.A.::25.0
#
# song format error
# 37610748::くにおくんの熱血サッカーリーグ::ねっけつ たいふーん♪::V.A.::80.0
#
# song format error
# 37610749::くにおくんの熱血サッカーリーグ::ゴール!!::V.A.::20.0
#
# song format error
# 37610750::くにおくんの熱血サッカーリーグ::試合終了::V.A.::40.0
#
# song format error
# 37610751::くにおくんの熱血サッカーリーグ::うんば・び・ぼんぼ♪::V.A.::55.0
#
# song format error
# 37610752::くにおくんの熱血サッカーリーグ::びきびき・さんば NO3♪::V.A.::40.0
#
# song format error
# 37610753::くにおくんの熱血サッカーリーグ::ごー・ごー・ねっけつ・すとらいかー♪::V.A.::40.0
#
# song format error
# 37610754::くにおくんの熱血サッカーリーグ::ねっけつ りーぐ・で・かーにばる♪::V.A.::35.0
#
# song format error
# 37610755::くにおくんの熱血サッカーリーグ::てくのす じゃぱん かっぷの てーま♪::V.A.::75.0
#
# song format error
# 37610756::くにおくんの熱血サッカーリーグ::優勝::V.A.::20.0
#
# song format error
# 37610757::くにおくんの熱血サッカーリーグ::エンディング::V.A.::25.0
#
# song format error
# 37610681::いけいけ熱血ホッケー部 すべってころんで大乱闘::オープニング::V.A.::20.0
#
# song format error
# 37610682::いけいけ熱血ホッケー部 すべってころんで大乱闘::タイトル::V.A.::20.0
#
# song format error
# 37610683::いけいけ熱血ホッケー部 すべってころんで大乱闘::対熱血高校ホッケー部のテーマ::V.A.::15.0
#
# song format error
# 37610685::いけいけ熱血ホッケー部 すべってころんで大乱闘::第1回戦::V.A.::15.0
#
# song format error
# 37610680::いけいけ熱血ホッケー部 すべってころんで大乱闘::テクノスジャパンロゴ::V.A.::25.0
#
# song format error
# 37610686::いけいけ熱血ホッケー部 すべってころんで大乱闘::INTERVAL::V.A.::15.0
#
# song format error
# 37610687::いけいけ熱血ホッケー部 すべってころんで大乱闘::3rd PERIOD::V.A.::20.0
#
# song format error
# 37610688::いけいけ熱血ホッケー部 すべってころんで大乱闘::試合終了::V.A.::5.0
#
# song format error
# 37610689::いけいけ熱血ホッケー部 すべってころんで大乱闘::中間デモ::V.A.::5.0
#
# song format error
# 37610690::いけいけ熱血ホッケー部 すべってころんで大乱闘::対熱血高校剣道部のテーマ::V.A.::5.0
#
# song format error
# 37610691::いけいけ熱血ホッケー部 すべってころんで大乱闘::第2回戦::V.A.::15.0
#
# song format error
# 37610692::いけいけ熱血ホッケー部 すべってころんで大乱闘::対熱血高校野球部のテーマ::V.A.::15.0
#
# song format error
# 37610693::いけいけ熱血ホッケー部 すべってころんで大乱闘::対百合ヶ丘女子ホッケークラブのテーマ::V.A.::5.0
#
# song format error
# 37610694::いけいけ熱血ホッケー部 すべってころんで大乱闘::対花園高校アメフトクラブのテーマ::V.A.::15.0
#
# song format error
# 37610695::いけいけ熱血ホッケー部 すべってころんで大乱闘::対谷花高校ローラーチームのテーマ::V.A.::5.0
#
# song format error
# 37610696::いけいけ熱血ホッケー部 すべってころんで大乱闘::対白銀高校ホッケー部のテーマ::V.A.::5.0
#
# song format error
# 37610697::いけいけ熱血ホッケー部 すべってころんで大乱闘::第7回戦::V.A.::5.0
#
# song format error
# 37610698::いけいけ熱血ホッケー部 すべってころんで大乱闘::第8回戦::V.A.::20.0
#
# song format error
# 37610699::いけいけ熱血ホッケー部 すべってころんで大乱闘::第9回戦::V.A.::20.0
#
# song format error
# 37610700::いけいけ熱血ホッケー部 すべってころんで大乱闘::第10回戦::V.A.::15.0
#
# song format error
# 37610701::いけいけ熱血ホッケー部 すべってころんで大乱闘::優勝::V.A.::5.0
#
# song format error
# 37610702::いけいけ熱血ホッケー部 すべってころんで大乱闘::エンディング::V.A.::5.0
# song format error
# 37610703::いけいけ熱血ホッケー部 すべってころんで大乱闘::ゲームオーバー::V.A.::5.0
#
# song format error
# 37610778::熱血!ストリートバスケット::スタッフロール::V.A.::20.0
#
# song format error
# 37610777::熱血!ストリートバスケット::エンディング::V.A.::20.0
#
# song format error
# 37610776::熱血!ストリートバスケット::ナイアガラステージ::V.A.::20.0
#
# song format error
# 37610775::熱血!ストリートバスケット::ラスベガスステージ::V.A.::20.0
#
# song format error
# 37610773::熱血!ストリートバスケット::サンフランシスコステージ::V.A.::20.0
#
# song format error
# 37610774::熱血!ストリートバスケット::対ラスベガス・チームのテーマ::V.A.::15.0
#
# song format error
# 37610772::熱血!ストリートバスケット::対サンフランシスコ・チームのテーマ::V.A.::20.0
#
# song format error
# 37610771::熱血!ストリートバスケット::ハワイステージ::V.A.::25.0
#
# song format error
# 37610770::熱血!ストリートバスケット::対ハワイ・チームのテーマ::V.A.::15.0
#
# song format error
# 37610769::熱血!ストリートバスケット::テキサスステージ::V.A.::25.0
#
# song format error
# 37610768::熱血!ストリートバスケット::対テキサス・チームのテーマ::V.A.::20.0
#
# song format error
# 37610766::熱血!ストリートバスケット::対フロリダ・チームのテーマ::V.A.::20.0
#
# song format error
# 37610765::熱血!ストリートバスケット::US NAVYステージ::V.A.::25.0
#
# song format error
# 37610764::熱血!ストリートバスケット::対 US NAVY・チームのテーマ::V.A.::20.0
#
# song format error
# 37610763::熱血!ストリートバスケット::ニューヨークステージ::V.A.::20.0
#
# song format error
# 37610762::熱血!ストリートバスケット::対ニューヨーク・チームのテーマ::V.A.::30.0
#
# song format error
# 37610761::熱血!ストリートバスケット::チーム選択::V.A.::45.0
#
# song format error
# 37610759::熱血!ストリートバスケット::オープニング::V.A.::40.0
#
# song format error
# 37610760::熱血!ストリートバスケット::モード選択::V.A.::25.0
#
# song format error
# 37610758::熱血!ストリートバスケット::テクノスジャパンロゴ::V.A.::45.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::60.0
#
# song format error
# 31654791::
#
# song format error
# European Intrigue::Tim Wynn::45.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 423031::源氏物语::浮舟::藤原道山::65.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 765579::映画“おくりびと”::おくりびと::古武道::15.0
#
# song format error
# 765584::ドラマ“少年时代”::绊~そして东云の空を共に翔よう~::古武道::10.0
#
# song format error
# 423031::源氏物语::浮舟::藤原道山::60.0
#
# song format error
# 803744::花衣梦衣::花衣梦衣::Rin'::20.0
#
# song format error
# 532324::モノノ怪::オボロ怪~oboroge~::高梨康治::75.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 28935319::
#
# song format error
# สั่น (Album Version)::Boy Sompob::100.0
#
# song format error
# 545405::花より男子ファイナル::チカラ合わせて::山下康介::10.0
#
# song format error
# 545389::花より男子ファイナル::サバイバル::山下康介::10.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::95.0
#
# song format error
# 2924300::
#
# song format error
#  Les Peulles Mortes (Autum Leaves)::Laura Fygi::85.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 4470537::Би дуртай
#
# song format error
# Ts.Khulan
#
# song format error
# D.Otgonbaatar
#
# song format error
# Bi durtai::Hurd::55.0
#
# song format error
# 4470518::Яг л чам шиг
#
# song format error
# Sükhzorig
#
# song format error
# D.Otgonbayar
#
# song format error
# Yag l cham shig::Hurd::40.0
#
# song format error
# 4470529::Намуухан орчлон
#
# song format error
# T.Erdenetsogt
#
# song format error
# D.Otgonbayar
#
# song format error
# Namuukhan orchlon::Hurd::65.0
#
# song format error
# 617067::『圣闘士星矢』より::ペガサス幻想(ファミソン オリジナル カラオケ(ショートサイズ))::桃井はるこ::75.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 1201288::Our Longest Winter::cecilia::eyes::25.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 592095::エル・カザド::hit it and run!::梶浦由記::10.0
#
# song format error
# 592076::エル・カザド::inca rose::梶浦由記::55.0
#
# song format error
# 592070::エル・カザド::sad yearning::梶浦由記::20.0
#
# song format error
# 592059::エル・カザド::desert sunset::梶浦由記::20.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 548681::风の谷のナウシカ::风の谷のナウシカ-オープニング-::山平宪嗣::20.0
#
# song format error
# ...
#
# song format error
# 31654822::
#
# song format error
# He's Escaping!::James Hannigan::25.0
#
# song format error
# 31654824::
#
# song format error
# Into the Volcano ::Tim Wynn::25.0
#
# song format error
# 548623::天空の城ラピュタ::空から降ってきた少女::山平宪嗣::75.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 4964190::School Days-スクールデイズ-::见ているだけで…::大久保薫::85.0
#
# song format error
# 27902653::Skit :: Killer Whales::Okasian::5.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::95.0
#
# song format error
# 33085638::
#
# song format error
# 新婚初夜メッセージ (春日野 紫子)::有栖川みや美::15.0
#
# song format error
# 4964190::School Days-スクールデイズ-::见ているだけで…::大久保薫::85.0
# song format error
# 31654791::
#
# song format error
# European Intrigue::Tim Wynn::45.0
#
# song format error
# 4948080::银魂::私と仕事どっちが大事なのとかいう女にはジャーマンスープレックス::Audio Highs::75.0
#
# song format error
# 570550::『Phantom ~Requiem for the Phantom~』オリジナルサウンドトラックVol.1::Requiem for the Phantom part I::伊藤真澄::30.0
#
# song format error
# 28590385::電脳コイル::戸惑い::斉藤恒芳::25.0
#
# song format error
# 426291251::Brand New Moves (Nomekop Remix)
#
# song format error
# ::Hey Violet::25.0
#
# song format error
# 29722334::For You
#
# song format error
# ::FiFi Rong::90.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 4964190::School Days-スクールデイズ-::见ているだけで…::大久保薫::85.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 29715639::The Vow
#
# song format error
# ::Steven Cravis::25.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 2772433::Sonata for piano & violin no.5:: III. Allegro molto::Isabelle Faust::25.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::95.0
#
# song format error
# 4951417::~Music Box~::Fairy Humming (ボーナストラック)::V.A.::25.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 4959806::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::黒ひげ海贼団の猛袭::田中公平::20.0
#
# song format error
# 4959807::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::サニー号の航海::田中公平::15.0
#
# song format error
# 4959808::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::冬岛?ドラム岛::田中公平::15.0
#
# song format error
# 4959809::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパーとの遭遇::田中公平::15.0
#
# song format error
# 4959810::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::魔女!?Dr.くれは::田中公平::15.0
#
# song format error
# 4959811::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::最低最悪の国王?ワポル::田中公平::15.0
#
# song format error
# 4959812::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::浮上!ブリキング号::田中公平::20.0
#
# song format error
# 4959813::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ラパーンの群れ::田中公平::15.0
#
# song format error
# 4959814::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::大暴れ!ゾロ&フランキー::田中公平::15.0
#
# song format error
# 4959815::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::大雪崩::田中公平::15.0
#
# song format error
# 4959816::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::険しい山::田中公平::15.0
#
# song format error
# 4959817::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ワポル兄弟の企み::田中公平::15.0
#
# song format error
# 4959818::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::イッシー20の密告::田中公平::15.0
#
# song format error
# 4959819::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::登れ::田中公平::15.0
#
# song format error
# 4959820::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::Dr.の住む城::田中公平::15.0
#
# song format error
# 4959821::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::肉っ!!!::田中公平::15.0
#
# song format error
# 4959822::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::青っ鼻の孤独::田中公平::40.0
#
# song format error
# 4959823::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ヤブ医者?Dr.ヒルルク::田中公平::15.0
#
# song format error
# 4959824::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::丸ハダカの叫び::田中公平::15.0
#
# song format error
# 4959825::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ぬくもり 2::田中公平::15.0
#
# song format error
# 4959826::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::桜が起こす奇迹::田中公平::15.0
#
# song format error
# 4959827::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ヒルルクとチョッパー::田中公平::15.0
#
# song format error
# 4959828::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::いつか、海に出ろ::田中公平::15.0
#
# song format error
# 4959829::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ヒルルクの别れ方::田中公平::15.0
#
# song format error
# 4959830::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::それぞれの戦い::田中公平::15.0
#
# song format error
# 4959831::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ギノ゛ゴ::田中公平::15.0
#
# song format error
# 4959832::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::纯真::田中公平::15.0
#
# song format error
# 4959833::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::まったく!!!!いい人生だった!!!!::田中公平::5.0
#
# song format error
# 4959834::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::舞い戻ったワポル::田中公平::20.0
#
# song format error
# 4959835::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::兄?ムッシュールの能力::田中公平::15.0
#
# song format error
# 4959836::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ドクロは信念の象徴::田中公平::15.0
#
# song format error
# 4959837::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS ルフィ 互角::田中公平::15.0
#
# song format error
# 4959838::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS ルフィ 败北::田中公平::15.0
#
# song format error
# 4959839::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS チョッパー::田中公平::15.0
#
# song format error
# 4959840::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::仲间::田中公平::15.0
#
# song format error
# 4959841::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS ルフィ 决着::田中公平::15.0
#
# song format error
# 4959842::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ランブルボール!!::田中公平::15.0
#
# song format error
# 4959843::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::人のドクロに手ェ出すな!!!::田中公平::15.0
#
# song format error
# 4959844::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::うるせェ!!!いこう!!!!::田中公平::15.0
#
# song format error
# 4959845::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::くれはの别れ方::田中公平::20.0
#
# song format error
# 4959846::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::冬に咲く、奇迹の桜::田中公平::15.0
#
# song format error
# 4959847::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク1::田中公平::15.0
#
# song format error
# 4959848::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::プレゼント::田中公平::15.0
#
# song format error
# 4959849::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ダキシメテ (チョッパートーク Version)::田中公平::15.0
#
# song format error
# 4959850::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク2::田中公平::20.0
#
# song format error
# 4959851::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::Dr.tony tony チョッパー::田中公平::15.0
#
# song format error
# 4959852::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::フレンズ::田中公平::15.0
#
# song format error
# 4959853::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク3::田中公平::5.0
#
# song format error
# 4959854::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::RUMBLE BALL チョッパー七段変形::田中公平::15.0
#
# song format error
# 4959855::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク4::田中公平::15.0
#
# song format error
# 4959856::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::Twinkle Twinkle::田中公平::15.0
#
# song format error
# 4959857::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパーマントーク!::田中公平::20.0
#
# song format error
# 4959858::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパーマンのうた::田中公平::15.0
#
# song format error
# 4959859::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::プレゼント (Remix Version) (ボーナストラック) - remix::田中公平::15.0
#
# song format error
# 4959860::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::フレンズ (Remix Version) (ボーナストラック) - remix::田中公平::25.0
#
# song format error
# 28576609::
#
# song format error
# ロビンとフランキーとブルック ~軍隊蟻たちの狙い~::浜口史郎::20.0
#
# song format error
# 28576630::
#
# song format error
# ベイビーダンス ~ダンスは求愛の印?~::田中公平::20.0
#
# song format error
# 28576624::
#
# song format error
# 先制攻撃 ~鼓動のボリュームを上げろ!~ ::浜口史郎::25.0
#
# song format error
# 28576631::
#
# song format error
# シキ ナミをあきらめる ~ルフィ登場~::浜口史郎::20.0
#
# song format error
# 28576623::
#
# song format error
# 最後の戦い ~渾身の巨人の雷斧(ギガント・トールアックス)~::浜口史郎::50.0
#
# song format error
# 4960621::バンブーブレード::STAR RISE::広桥凉::40.0
#
# song format error
# 4960603::バンブーブレード::BAMBOO BEAT::広桥凉::25.0
#
# song format error
# 26884168::
#
# song format error
# Age Of Loneliness (Enigmatic Club Mix)::Enigma::5.0
#
# song format error
# 26884170::
#
# song format error
# Gravity Of Love (Judgement Day Club Mix)::Enigma::5.0
#
# song format error
# 26884172::
#
# song format error
# Light Of Your Smile::Enigma::5.0
#
# song format error
# 26884175::
#
# song format error
# Mea Culpa Part Ii (Original Version)::Enigma::5.0
#
# song format error
# 26884180::
#
# song format error
# Principles Of Lust (Omen Mix)::Enigma::5.0
#
# song format error
# 26884182::
#
# song format error
# Return To Innocence (380 Midnight)::Enigma::5.0
#
# song format error
# 26884183::
#
# song format error
# Return To Innocence (Long)::Enigma::5.0
#
# song format error
# 26884186::
#
# song format error
# Sadeness Part 1 (Meditation Mix)::Enigma::5.0
#
# song format error
# 27511866::첫 사랑니 (Rum Pum Pum Pum)
#
# song format error
# ::f(x)::95.0
#
# song format error
# 32272105::
#
# song format error
# Wonderful Love (DJ Raf Remix)::Money Penny::95.0
#
# song format error
# 545791::パパとムスメの7日间::“星屑サンセット”~チェロ ver.::山下康介::50.0
#
# song format error
# 570606::『Phantom ~Requiem for the Phantom~』オリジナルサウンドトラックVol.1::Requiem for the Phantom part III::伊藤真澄::25.0
#
# song format error
# 570567::『Phantom ~Requiem for the Phantom~』オリジナルサウンドトラックVol.1::Canzone of death part II::伊藤真澄::25.0
#
# song format error
# 570625::『Phantom ~Requiem for the Phantom~』オリジナルサウンドトラックVol.1::Whisper of meadow::伊藤真澄::25.0
#
# song format error
# 32408314::
#
# song format error
# Kishinjou set 03 ~ 運河を行き交う人妖::凛::20.0
#
# song format error
# 32408315::
#
# song format error
# Kishinjou set 04 ~ 柳の下のデュラハン::凛::15.0
#
# song format error
# 32408321::
#
# song format error
# Kishinjou set 09 ~ 空中に沈む輝針城::凛::5.0
#
# song format error
# 32408322::
#
# song format error
# Kishinjou set 10 ~ リバースイデオロギー::凛::20.0
#
# song format error
# 32408323::
#
# song format error
# Kishinjou set 11 ~ 針小棒大の天守閣::凛::15.0
#
# song format error
# 32408324::
#
# song format error
# Kishinjou set 12 ~ 輝く針の小人族::凛::20.0
#
# song format error
# 32408328::
#
# song format error
# Kishinjou set 16 ~ 不思議な不思議な道具達::凛::5.0
#
# song format error
# 32408334::
#
# song format error
# Amanojaku set 00 ~ 反則の狼煙を上げろ::凛::5.0
#
# song format error
# 32408335::
#
# song format error
# Amanojaku set 01 ~ 不可能弾幕には反則を::凛::15.0
#
# song format error
# 32408338::
#
# song format error
# Amanojaku set 03 ~ ロマンチック逃飛行::凛::5.0
#
# song format error
# 32408339::
#
# song format error
# Amanojaku set 04 ~ 永遠の三日天下::凛::15.0
#
# song format error
# 746863::黒い海に红く
#
# song format error
# (东方绯想天)::はちみつくまさん::25.0
#
# song format error
# 746854::无间の钟　~ Infinite Nightmare
#
# song format error
# (东方ダブルスポイラー)::はちみつくまさん::25.0
#
# song format error
# 31477705::
#
# song format error
# Johann Sebastian Bach: Goldberg Variations, BWV 988 - Variation 9 Canone alla Terza::Elena Barshai::20.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 4959806::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::黒ひげ海贼団の猛袭::田中公平::20.0
#
# song format error
# 4959807::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::サニー号の航海::田中公平::15.0
#
# song format error
# 4959808::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::冬岛?ドラム岛::田中公平::15.0
#
# song format error
# 4959809::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパーとの遭遇::田中公平::15.0
#
# song format error
# 4959810::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::魔女!?Dr.くれは::田中公平::15.0
#
# song format error
# 4959811::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::最低最悪の国王?ワポル::田中公平::15.0
#
# song format error
# 4959812::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::浮上!ブリキング号::田中公平::20.0
#
# song format error
# 4959813::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ラパーンの群れ::田中公平::15.0
#
# song format error
# 4959814::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::大暴れ!ゾロ&フランキー::田中公平::15.0
#
# song format error
# 4959815::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::大雪崩::田中公平::5.0
#
# song format error
# 4959816::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::険しい山::田中公平::15.0
#
# song format error
# 4959817::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ワポル兄弟の企み::田中公平::15.0
#
# song format error
# 4959818::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::イッシー20の密告::田中公平::15.0
#
# song format error
# 4959819::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::登れ::田中公平::15.0
#
# song format error
# 4959820::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::Dr.の住む城::田中公平::15.0
#
# song format error
# 4959821::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::肉っ!!!::田中公平::15.0
#
# song format error
# 4959822::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::青っ鼻の孤独::田中公平::35.0
#
# song format error
# 4959823::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ヤブ医者?Dr.ヒルルク::田中公平::15.0
#
# song format error
# 4959824::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::丸ハダカの叫び::田中公平::15.0
#
# song format error
# 4959825::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ぬくもり 2::田中公平::15.0
#
# song format error
# 4959826::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::桜が起こす奇迹::田中公平::15.0
#
# song format error
# 4959827::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ヒルルクとチョッパー::田中公平::15.0
#
# song format error
# 4959828::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::いつか、海に出ろ::田中公平::15.0
#
# song format error
# 4959829::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ヒルルクの别れ方::田中公平::15.0
#
# song format error
# 4959830::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::それぞれの戦い::田中公平::15.0
#
# song format error
# 4959831::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ギノ゛ゴ::田中公平::15.0
#
# song format error
# 4959832::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::纯真::田中公平::15.0
#
# song format error
# 4959833::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::まったく!!!!いい人生だった!!!!::田中公平::15.0
#
# song format error
# 4959834::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::舞い戻ったワポル::田中公平::20.0
#
# song format error
# 4959835::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::兄?ムッシュールの能力::田中公平::15.0
#
# song format error
# 4959836::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ドクロは信念の象徴::田中公平::15.0
#
# song format error
# 4959837::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS ルフィ 互角::田中公平::5.0
#
# song format error
# 4959838::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS ルフィ 败北::田中公平::15.0
#
# song format error
# 4959839::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS チョッパー::田中公平::15.0
#
# song format error
# 4959840::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::仲间::田中公平::15.0
#
# song format error
# 4959841::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ムッシュール VS ルフィ 决着::田中公平::15.0
#
# song format error
# 4959842::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ランブルボール!!::田中公平::15.0
#
# song format error
# 4959843::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::人のドクロに手ェ出すな!!!::田中公平::15.0
#
# song format error
# 4959844::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::うるせェ!!!いこう!!!!::田中公平::15.0
#
# song format error
# 4959845::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::くれはの别れ方::田中公平::20.0
#
# song format error
# 4959846::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::冬に咲く、奇迹の桜::田中公平::15.0
#
# song format error
# 4959847::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク1::田中公平::15.0
#
# song format error
# 4959848::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::プレゼント::田中公平::5.0
#
# song format error
# 4959849::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::ダキシメテ (チョッパートーク Version)::田中公平::15.0
#
# song format error
# 4959850::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク2::田中公平::20.0
#
# song format error
# 4959851::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::Dr.tony tony チョッパー::田中公平::15.0
#
# song format error
# 4959852::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::フレンズ::田中公平::15.0
#
# song format error
# 4959853::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク3::田中公平::15.0
#
# song format error
# 4959854::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::RUMBLE BALL チョッパー七段変形::田中公平::5.0
#
# song format error
# 4959855::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパートーク4::田中公平::15.0
#
# song format error
# 4959856::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::Twinkle Twinkle::田中公平::15.0
#
# song format error
# 4959857::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパーマントーク!::田中公平::20.0
#
# song format error
# 4959858::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::チョッパーマンのうた::田中公平::15.0
#
# song format error
# 4959859::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::プレゼント (Remix Version) (ボーナストラック) - remix::田中公平::5.0
#
# song format error
# 4959860::ワンピース エピソードオブチョッパー+冬に咲く、奇迹の桜::フレンズ (Remix Version) (ボーナストラック) - remix::田中公平::25.0
#
# song format error
# 28576609::
#
# song format error
# ロビンとフランキーとブルック ~軍隊蟻たちの狙い~::浜口史郎::20.0
#
# song format error
# 28576623::
#
# song format error
# 最後の戦い ~渾身の巨人の雷斧(ギガント・トールアックス)~::浜口史郎::50.0
#
# song format error
# 28576624::
#
# song format error
# 先制攻撃 ~鼓動のボリュームを上げろ!~ ::浜口史郎::25.0
#
# song format error
# 28576630::
#
# song format error
# ベイビーダンス ~ダンスは求愛の印?~::田中公平::20.0
#
# song format error
# 28576631::
#
# song format error
# シキ ナミをあきらめる ~ルフィ登場~::浜口史郎::20.0
#
# song format error
# 1375664::Suite No. 3 In G Minor, BWV 808 IV. Sarabande - Les Agréments De La Même Sarabande
#
# song format error
# ::Glenn Gould::20.0
#
# song format error
# 29722334::For You
#
# song format error
# ::FiFi Rong::90.0
#
# song format error
# 4948185::beatmania IIDX 16 EMPRESS [ELECTRO-TECH]::Mind Mapping::V.A.::5.0
#
# song format error
# 4948200::beatmania IIDX 16 EMPRESS [ASIAN JANGLE]::Kung-fu Empire::V.A.::15.0
#
# song format error
# 4948206::beatmania IIDX 16 EMPRESS [BUCHIAGE TRANCE]::Cyber Force -DJ Yoshitaka Remix-::V.A.::5.0
#
# song format error
# 4948191::beatmania IIDX 16 EMPRESS [DREAM TRANCE]::Fly Above::V.A.::5.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 27704949::
#
# song format error
# 투명인간 (feat. 있다) (prod. The Quiett)::Fana::5.0
#
# song format error
# 27704951::
#
# song format error
# Code Name : SOUL (prod. Vida Loca)::Fana::5.0
#
# song format error
# 4964190::School Days-スクールデイズ-::见ているだけで…::大久保薫::85.0
#
# song format error
# 5157818::Divertimento in D, K.334 - 3. Menuetto - Trio -
#
# song format error
# Menuetto::Wiener MozartEnsemble::20.0
#
# song format error
# 725347::fortissimo-the ultimate crisis- (instrumental)
#
# song format error
# ::fripSide::50.0

# %%
parse_file2("./ori_data/popular.playlist", "./pro_data/popular_playlist.pkl", "./pro_data/popular_song.pkl")
# Out:
# song format error
# 1870957::彩云国物语 セカンドシリーズ::君を想う::梁邦彦::80.0
#
# song format error
# 4965888::桃华月惮::龙皇-リュウオウ-::多田彰文::25.0
#
# song format error
# 456177::true tears::一阵の风::菊地創::95.0
#
# song format error
# 22642373::
#
# song format error
#  FAIRY TAIL メインテーマ -Slow ver.-::高梨康治::95.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::60.0
#
# song format error
# 4954593::リズム天国全曲集::恋の実験室::V.A.::55.0
#
# song format error
# 4954596::リズム天国全曲集::シンクロ::V.A.::60.0
#
# song format error
# 31654811::
#
# song format error
# American Cowboys::Tim Wynn::65.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::60.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::60.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::60.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 376653::野弧禅狂叱(宿香之战)
#
# song format error
# ::霹雳英雄::5.0
#
# song format error
# 374524::赎?罪
#
# song format error
# 赎罪岩::霹雳英雄::15.0
#
# song format error
# 31563610::
#
# song format error
# 苍之礼赞::花之祭P::65.0
#
# song format error
# 37610597::ダウンタウン熱血物語::公園/河原にて~ひとときのやすらぎ~::V.A.::75.0
#
# song format error
# 37610748::くにおくんの熱血サッカーリーグ::ねっけつ たいふーん♪::V.A.::80.0
#
# song format error
# 37610755::くにおくんの熱血サッカーリーグ::てくのす じゃぱん かっぷの てーま♪::V.A.::75.0
#
# song format error
# 37610745::くにおくんの熱血サッカーリーグ::ゲームモード選択::V.A.::75.0
#
# song format error
# 37610643::ダウンタウン熱血行進曲 それゆけ大運動会::オープニングファンファーレ::V.A.::70.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::90.0
#
# song format error
# 405599088::Make Them Wheels Roll
#
# song format error
# ::SAFIA::100.0
#
# song format error
# 424496188::大王叫我来巡山 - （原唱：
#
# song format error
#  贾乃亮/贾云馨）::流浪的蛙蛙::65.0
#
# song format error
# 19169096::
#
# song format error
#  Time to Say Goodbye (Con te partirò)::Sarah Brightman::100.0
#
# song format error
# 26902203::What’s your name? (collaboration with 壇蜜)
#
# song format error
# ::SoulJa::100.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::95.0
#
# song format error
# 4954596::リズム天国全曲集::シンクロ::V.A.::60.0
#
# song format error
# 32272105::
#
# song format error
# Wonderful Love (DJ Raf Remix)::Money Penny::95.0
#
# song format error
# 33054290::
#
# song format error
# Heartbeats::Dabin::95.0
#
# song format error
# 427373827::Champions (From "Hands of Stone")
#
# song format error
# ::Usher::30.0
#
# song format error
# 29242687::「コード・エテスウェイ (Class::ETHES_WEI=>extends.COMMUNI_SAT/.)」::霜月はるか::70.0

# %% [markdown]
# ## 使用推荐系统库Surprise构建模型

# %%
import os
import io

from surprise import KNNBaseline, Reader
from surprise import Dataset

# 重建歌单id到歌单名的映射字典
id_name_dic = pickle.load(open("./pro_data/popular_playlist.pkl","rb"))
print("加载歌单id到歌单名的映射字典完成...")
# 重建歌单名到歌单id的映射字典
name_id_dic = {}
for playlist_id in id_name_dic:
    name_id_dic[id_name_dic[playlist_id]] = playlist_id
print("加载歌单名到歌单id的映射字典完成...")


file_path = os.path.expanduser('./pro_data/popular_music_suprise_format.txt')
# 指定文件格式
reader = Reader(line_format='user item rating timestamp', sep=',')
# 从文件读取数据
music_data = Dataset.load_from_file(file_path, reader=reader)
# 计算歌曲和歌曲之间的相似度
print("构建数据集...")
trainset = music_data.build_full_trainset()
#sim_options = {'name': 'pearson_baseline', 'user_based': False}
# Out:
# 加载歌单id到歌单名的映射字典完成...
# 加载歌单名到歌单id的映射字典完成...
# 构建数据集...

# %%
list(id_name_dic.keys())[2]
# Out:
# '308252386'

# %%
print(id_name_dic[list(id_name_dic.keys())[2]])
# Out:
# 《从你的全世界路过》电影原声带

# %%
trainset.n_items
# Out:
# 130573

# %%
trainset.n_users
# Out:
# 3771

# %% [markdown]
# ### 查找最近的user(在这里是歌单)

# %%
print("开始训练模型...")
#sim_options = {'user_based': False}
#algo = KNNBaseline(sim_options=sim_options)
algo = KNNBaseline()
algo.train(trainset)

current_playlist = list(name_id_dic.keys())[39]
print("歌单名称", current_playlist)

# 取出近邻
# 映射名字到id
playlist_id = name_id_dic[current_playlist]
print("歌单id", playlist_id)
# 取出来对应的内部user id => to_inner_uid
playlist_inner_id = algo.trainset.to_inner_uid(playlist_id)
print("内部id", playlist_inner_id)

playlist_neighbors = algo.get_neighbors(playlist_inner_id, k=10)

# 把歌曲id转成歌曲名字
# to_raw_uid映射回去
playlist_neighbors = (algo.trainset.to_raw_uid(inner_id)
                       for inner_id in playlist_neighbors)
playlist_neighbors = (id_name_dic[playlist_id]
                       for playlist_id in playlist_neighbors)

print()
print("和歌单 《", current_playlist, "》 最接近的10个歌单为：\n")
for playlist in playlist_neighbors:
    print(playlist, algo.trainset.to_inner_uid(name_id_dic[playlist]))
# Out:
# 开始训练模型...
# Estimating biases using als...
# D:\Anaconda\install\lib\site-packages\surprise\prediction_algorithms\algo_base.py:51: UserWarning: train() is deprecated. Use fit() instead
#   warnings.warn('train() is deprecated. Use fit() instead', UserWarning)
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# 歌单名称 卖血哥翻唱专辑
# 歌单id 132021932
# 内部id 1255
#
# 和歌单 《 卖血哥翻唱专辑 》 最接近的10个歌单为：
#
# 评论数过500的鬼畜、调教及翻唱精品 586
# 【普通disco】各版本合集 622
# 《原来翻唱也可以这么好听~》同步更新中... 883
# 自用·～安静的 在闲暇时听这些歌 887
# 华语翻唱│同一旋律男女别韵味 ❀ 1041
# ♫ 越听越好听的中文歌 1481
# 【华语】冷门好听の优质男声⭐ 1510
# 热门华语（AB站向？ ） 2216
# 写歌的人假正经，听歌的人最无情。 2783
# 單 身 情 歌 3168

# %% [markdown]
# ### 针对用户进行预测

# %%
import pickle
# 重建歌曲id到歌曲名的映射字典
song_id_name_dic = pickle.load(open("./pro_data/popular_song.pkl","rb"))
print("加载歌曲id到歌曲名的映射字典完成...")
# 重建歌曲名到歌曲id的映射字典
song_name_id_dic = {}
for song_id in song_id_name_dic:
    song_name_id_dic[song_id_name_dic[song_id]] = song_id
print("加载歌曲名到歌曲id的映射字典完成...")
# Out:
# 加载歌曲id到歌曲名的映射字典完成...
# 加载歌曲名到歌曲id的映射字典完成...

# %%
#内部编码的4号用户
user_inner_id = 4
user_rating = trainset.ur[user_inner_id]
items = map(lambda x:x[0], user_rating)
for song in items:
    print(algo.predict(user_inner_id, song, r_ui=1), song_id_name_dic[algo.trainset.to_raw_iid(song)])
# Out:
# user: 4          item: 361        r_ui = 1.00   est = 1.00   {'was_impossible': False} 家	许巍
# user: 4          item: 362        r_ui = 1.00   est = 1.00   {'was_impossible': False} 老街	李荣浩
# user: 4          item: 363        r_ui = 1.00   est = 1.00   {'was_impossible': False} 滴答	侃侃
# user: 4          item: 364        r_ui = 1.00   est = 1.00   {'was_impossible': False} 彩虹	周杰伦
# user: 4          item: 365        r_ui = 1.00   est = 1.00   {'was_impossible': False} 米店	张玮玮和郭龙
# user: 4          item: 366        r_ui = 1.00   est = 1.00   {'was_impossible': False} 情人	Beyond
# user: 4          item: 367        r_ui = 1.00   est = 1.00   {'was_impossible': False} 喜欢你	Beyond
# user: 4          item: 220        r_ui = 1.00   est = 1.00   {'was_impossible': False} 灰姑娘	郑钧
# user: 4          item: 235        r_ui = 1.00   est = 1.00   {'was_impossible': False} 安和桥	宋冬野
# user: 4          item: 240        r_ui = 1.00   est = 1.00   {'was_impossible': False} 去大理	郝云
# user: 4          item: 368        r_ui = 1.00   est = 1.00   {'was_impossible': False} 好久不见	陈奕迅
# user: 4          item: 369        r_ui = 1.00   est = 1.00   {'was_impossible': False} 那些花儿	朴树
# user: 4          item: 50         r_ui = 1.00   est = 1.00   {'was_impossible': False} 当你老了	赵照
# user: 4          item: 244        r_ui = 1.00   est = 1.00   {'was_impossible': False} 且听风吟	朴树
# user: 4          item: 264        r_ui = 1.00   est = 1.00   {'was_impossible': False} 同桌的你	老狼
# user: 4          item: 297        r_ui = 1.00   est = 1.00   {'was_impossible': False} 斑马，斑马	宋冬野
# user: 4          item: 370        r_ui = 1.00   est = 1.00   {'was_impossible': False} 花房姑娘(翻唱崔健)	花粥
# user: 4          item: 339        r_ui = 1.00   est = 1.00   {'was_impossible': False} 北方的女王(demo)	尧十三
# user: 4          item: 371        r_ui = 1.00   est = 1.00   {'was_impossible': False} 外面的世界	莫文蔚
# user: 4          item: 372        r_ui = 1.00   est = 1.00   {'was_impossible': False} 我真的受伤了	王菀之
# user: 4          item: 373        r_ui = 1.00   est = 1.00   {'was_impossible': False} 再见吧喵小姐	王晓天
# user: 4          item: 374        r_ui = 1.00   est = 1.00   {'was_impossible': False} 你知道我在等你吗	张洪量

# %% [markdown]
# ### 用矩阵分解进行预测

# %%
### 使用NMF
from surprise import NMF, evaluate
from surprise import Dataset

file_path = os.path.expanduser('./pro_data/popular_music_suprise_format.txt')
# 指定文件格式
reader = Reader(line_format='user item rating timestamp', sep=',')
# 从文件读取数据
music_data = Dataset.load_from_file(file_path, reader=reader)
# 构建数据集和建模
algo = NMF()
trainset = music_data.build_full_trainset()
algo.train(trainset)
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\prediction_algorithms\algo_base.py:51: UserWarning: train() is deprecated. Use fit() instead
#   warnings.warn('train() is deprecated. Use fit() instead', UserWarning)

# %%
user_inner_id = 4
user_rating = trainset.ur[user_inner_id]
items = map(lambda x:x[0], user_rating)
for song in items:
    print(algo.predict(algo.trainset.to_raw_uid(user_inner_id), algo.trainset.to_raw_iid(song), r_ui=1), song_id_name_dic[algo.trainset.to_raw_iid(song)])
# Out:
# user: 69758545   item: 167751     r_ui = 1.00   est = 1.00   {'was_impossible': False} 家	许巍
# user: 69758545   item: 133998     r_ui = 1.00   est = 1.00   {'was_impossible': False} 老街	李荣浩
# user: 69758545   item: 25638325   r_ui = 1.00   est = 1.00   {'was_impossible': False} 滴答	侃侃
# user: 69758545   item: 185809     r_ui = 1.00   est = 1.00   {'was_impossible': False} 彩虹	周杰伦
# user: 69758545   item: 26494698   r_ui = 1.00   est = 1.00   {'was_impossible': False} 米店	张玮玮和郭龙
# user: 69758545   item: 347355     r_ui = 1.00   est = 1.00   {'was_impossible': False} 情人	Beyond
# user: 69758545   item: 346073     r_ui = 1.00   est = 1.00   {'was_impossible': False} 喜欢你	Beyond
# user: 69758545   item: 186842     r_ui = 1.00   est = 1.00   {'was_impossible': False} 灰姑娘	郑钧
# user: 69758545   item: 27646205   r_ui = 1.00   est = 1.00   {'was_impossible': False} 安和桥	宋冬野
# user: 69758545   item: 28977819   r_ui = 1.00   est = 1.00   {'was_impossible': False} 去大理	郝云
# user: 69758545   item: 65538      r_ui = 1.00   est = 1.00   {'was_impossible': False} 好久不见	陈奕迅
# user: 69758545   item: 139377     r_ui = 1.00   est = 1.00   {'was_impossible': False} 那些花儿	朴树
# user: 69758545   item: 26090100   r_ui = 1.00   est = 1.00   {'was_impossible': False} 当你老了	赵照
# user: 69758545   item: 139359     r_ui = 1.00   est = 1.00   {'was_impossible': False} 且听风吟	朴树
# user: 69758545   item: 5281327    r_ui = 1.00   est = 1.00   {'was_impossible': False} 同桌的你	老狼
# user: 69758545   item: 27646199   r_ui = 1.00   est = 1.00   {'was_impossible': False} 斑马，斑马	宋冬野
# user: 69758545   item: 27514451   r_ui = 1.00   est = 1.00   {'was_impossible': False} 花房姑娘(翻唱崔健)	花粥
# user: 69758545   item: 28381611   r_ui = 1.00   est = 1.00   {'was_impossible': False} 北方的女王(demo)	尧十三
# user: 69758545   item: 276904     r_ui = 1.00   est = 1.00   {'was_impossible': False} 外面的世界	莫文蔚
# user: 69758545   item: 297711     r_ui = 1.00   est = 1.00   {'was_impossible': False} 我真的受伤了	王菀之
# user: 69758545   item: 28191648   r_ui = 1.00   est = 1.00   {'was_impossible': False} 再见吧喵小姐	王晓天
# user: 69758545   item: 191791     r_ui = 1.00   est = 1.00   {'was_impossible': False} 你知道我在等你吗	张洪量

# %% [markdown]
# ## 模型存储

# %%
import surprise
surprise.dump.dump('./model/recommendation.model', algo=algo)
# 可以用下面的方式载入
algo = surprise.dump.load('./model/recommendation.model')

# %% [markdown]
# ## 不同的推荐系统算法评估

# %%
# 载入数据
import os
from surprise import Reader, Dataset
# 指定文件路径
file_path = os.path.expanduser('./pro_data/popular_music_suprise_format.txt')
# 指定文件格式
reader = Reader(line_format='user item rating timestamp', sep=',')
# 从文件读取数据
music_data = Dataset.load_from_file(file_path, reader=reader)
# 分成5折
music_data.split(n_folds=5)

# %%
music_data

# %%
music_data.raw_ratings[:20]
# Out:
# [('428320388', '28731643', 1.0, '1300000'),
#  ('90448075', '5254908', 1.0, '1300000'),
#  ('16486092', '26830567', 1.0, '1300000'),
#  ('38014760', '261433', 1.0, '1300000'),
#  ('430012080', '5273228', 1.0, '1300000'),
#  ('148474853', '16435049', 1.0, '1300000'),
#  ('54840743', '5283432', 1.0, '1300000'),
#  ('81785948', '331579', 1.0, '1300000'),
#  ('93476766', '125399', 1.0, '1300000'),
#  ('69000117', '189259', 1.0, '1300000'),
#  ('95990977', '29750124', 1.0, '1300000'),
#  ('56842248', '22682066', 1.0, '1300000'),
#  ('142425394', '29812280', 1.0, '1300000'),
#  ('4990469', '5284516', 1.0, '1300000'),
#  ('168780705', '29544645', 1.0, '1300000'),
#  ('422392659', '28308080', 1.0, '1300000'),
#  ('34670012', '28912419', 1.0, '1300000'),
#  ('79906957', '32217107', 1.0, '1300000'),
#  ('127886176', '135497', 1.0, '1300000'),
#  ('92513299', '41652722', 1.0, '1300000')]

# %%
### 使用NormalPredictor
from surprise import NormalPredictor, evaluate
algo = NormalPredictor()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm NormalPredictor.
#
# ------------
# Fold 1
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 2
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 3
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 4
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 5
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# ------------
# Mean RMSE: 0.0000
# Mean MAE : 0.0000
# ------------
# ------------

# %%
### 使用BaselineOnly
from surprise import BaselineOnly, evaluate
algo = BaselineOnly()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm BaselineOnly.
#
# ------------
# Fold 1
# Estimating biases using als...
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 2
# Estimating biases using als...
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 3
# Estimating biases using als...
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 4
# Estimating biases using als...
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 5
# Estimating biases using als...
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# ------------
# Mean RMSE: 0.0000
# Mean MAE : 0.0000
# ------------
# ------------

# %%
### 使用基础版协同过滤
from surprise import KNNBasic, evaluate
algo = KNNBasic()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 4
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 5
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# ------------
# Mean RMSE: 0.0000
# Mean MAE : 0.0000
# ------------
# ------------

# %%
### 使用均值协同过滤
from surprise import KNNWithMeans, evaluate
algo = KNNWithMeans()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm KNNWithMeans.
#
# ------------
# Fold 1
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 2
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 3
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 4
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 5
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# ------------
# Mean RMSE: 0.0000
# Mean MAE : 0.0000
# ------------
# ------------

# %%
### 使用协同过滤baseline
from surprise import KNNBaseline, evaluate
algo = KNNBaseline()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm KNNBaseline.
#
# ------------
# Fold 1
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 2
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 3
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 4
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# Fold 5
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.0000
# MAE:  0.0000
# ------------
# ------------
# Mean RMSE: 0.0000
# Mean MAE : 0.0000
# ------------
# ------------

# %%
### 使用SVD
from surprise import SVD, evaluate
algo = SVD()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.0407
# MAE:  0.0192
# ------------
# Fold 2
# RMSE: 0.0407
# MAE:  0.0192
# ------------
# Fold 3
# RMSE: 0.0406
# MAE:  0.0191
# ------------
# Fold 4
# RMSE: 0.0406
# MAE:  0.0191
# ------------
# Fold 5
# RMSE: 0.0405
# MAE:  0.0191
# ------------
# ------------
# Mean RMSE: 0.0406
# Mean MAE : 0.0191
# ------------
# ------------

# %%
### 使用SVD++
from surprise import SVDpp, evaluate
algo = SVDpp()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
# Out:
# D:\Anaconda\install\lib\site-packages\surprise\evaluate.py:66: UserWarning: The evaluate() method is deprecated. Please use model_selection.cross_validate() instead.
#   'model_selection.cross_validate() instead.', UserWarning)
# D:\Anaconda\install\lib\site-packages\surprise\dataset.py:193: UserWarning: Using data.split() or using load_from_folds() without using a CV iterator is now deprecated.
#   UserWarning)
# Evaluating RMSE, MAE of algorithm SVDpp.
#
# ------------
# Fold 1

# %%
### 使用NMF
from surprise import NMF
algo = NMF()
perf = evaluate(algo, music_data, measures=['RMSE', 'MAE'])
print_perf(perf)
